# %% [markdown]
# ## Introduction
#
# ### In this notebook we use [UNet] segmentation model to remove background as a preprocessing step.

# %% [markdown]
# ### Libraries 📚⬇

# %%
import os, cv2
import numpy as np
import pandas as pd
import random, tqdm
#import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")
from PIL import Image
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
import albumentations as album
from torchvision.transforms.functional import adjust_sharpness
from skimage import filters

# %%
import segmentation_models_pytorch as smp

from segmentation_models_pytorch import utils
import segmentation_models_pytorch.utils.metrics

# %%
#!pip install -q -U segmentation-models-pytorch albumentations > /dev/null

# %% [markdown]
# ### Defining train / val / test directories 📁

# %%
DATA_DIR = '../data/tiff_v3/128_modified/'

random_crop_size = 128

x_train_dir = os.path.join(DATA_DIR, 'train')
y_train_dir = os.path.join(DATA_DIR, 'train_labels')

x_valid_dir = os.path.join(DATA_DIR, 'val')
y_valid_dir = os.path.join(DATA_DIR, 'val_labels')

x_test_dir = os.path.join(DATA_DIR, 'test')
y_test_dir = os.path.join(DATA_DIR, 'test_labels')

# %%
class_dict = pd.read_csv("../data/label_class_dict.csv")
# Get class names
class_names = class_dict['name'].tolist()
# Get class RGB values
class_rgb_values = class_dict[['r','g','b']].values.tolist()

print('All dataset classes and their corresponding RGB values in labels:')
print('Class Names: ', class_names)
print('Class RGB values: ', class_rgb_values)
# Out:
# All dataset classes and their corresponding RGB values in labels:
# Class Names:  ['background', 'building']
# Class RGB values:  [[0, 0, 0], [255, 255, 255]]

# %% [markdown]
# #### Shortlist specific classes to segment

# %%
# Useful to shortlist specific classes in datasets with large number of classes
select_classes = ['background', 'building']

# Get RGB values of required classes
select_class_indices = [class_names.index(cls.lower()) for cls in select_classes]
select_class_rgb_values =  np.array(class_rgb_values)[select_class_indices]

print('Selected classes and their corresponding RGB values in labels:')
print('Class Names: ', class_names)
print('Class RGB values: ', class_rgb_values)
# Out:
# Selected classes and their corresponding RGB values in labels:
# Class Names:  ['background', 'building']
# Class RGB values:  [[0, 0, 0], [255, 255, 255]]

# %% [markdown]
# ### Helper functions for viz. & one-hot encoding/decoding

# %%
# helper function for data visualization
def visualize(**images):
    """
    Plot images in one row
    """
    n_images = len(images)
    plt.figure(figsize=(20,8))
    for idx, (name, image) in enumerate(images.items()):
        plt.subplot(1, n_images, idx + 1)
        plt.xticks([]); 
        plt.yticks([])
        # get title from the parameter names
        plt.title(name.replace('_',' ').title(), fontsize=20)
        plt.imshow(image)
    plt.show()

# Perform one hot encoding on label
def one_hot_encode(label, label_values):
    """
    Convert a segmentation image label array to one-hot format
    by replacing each pixel value with a vector of length num_classes
    # Arguments
        label: The 2D array segmentation image label
        label_values
        
    # Returns
        A 2D array with the same width and hieght as the input, but
        with a depth size of num_classes
    """
    
    semantic_map = []
    for colour in label_values:
        equality = np.equal(label, colour)
        class_map = np.all(equality, axis = -1)
        semantic_map.append(class_map)
    semantic_map = np.stack(semantic_map, axis=-1)

    return semantic_map
    
# Perform reverse one-hot-encoding on labels / preds
def reverse_one_hot(image):
    """
    Transform a 2D array in one-hot format (depth is num_classes),
    to a 2D array with only 1 channel, where each pixel value is
    the classified class key.
    # Arguments
        image: The one-hot format image 
        
    # Returns
        A 2D array with the same width and hieght as the input, but
        with a depth size of 1, where each pixel value is the classified 
        class key.
    """
    x = np.argmax(image, axis = -1)
    return x

# Perform colour coding on the reverse-one-hot outputs
def colour_code_segmentation(image, label_values):
    """
    Given a 1-channel array of class keys, colour code the segmentation results.
    # Arguments
        image: single channel array where each value represents the class key.
        label_values

    # Returns
        Colour coded image for segmentation visualization
    """
    colour_codes = np.array(label_values)
    x = colour_codes[image.astype(int)]

    return x

# %%
class BuildingsDataset(torch.utils.data.Dataset):

    """Massachusetts Buildings Dataset. Read images, apply augmentation and preprocessing transformations.
    
    Args:
        images_dir (str): path to images folder
        masks_dir (str): path to segmentation masks folder
        class_rgb_values (list): RGB values of select classes to extract from segmentation mask
        augmentation (albumentations.Compose): data transfromation pipeline 
            (e.g. flip, scale, etc.)
        preprocessing (albumentations.Compose): data preprocessing 
            (e.g. noralization, shape manipulation, etc.)
    
    """
    
    def __init__(
            self, 
            images_dir, 
            masks_dir, 
            class_rgb_values=None, 
            augmentation=None, 
            preprocessing=None,
    ):
        
        
        self.image_paths = [os.path.join(images_dir, image_id) for image_id in sorted(os.listdir(images_dir))]
        self.mask_paths = [os.path.join(masks_dir, image_id) for image_id in sorted(os.listdir(masks_dir))]            

        self.class_rgb_values = class_rgb_values
        self.augmentation = augmentation
        self.preprocessing = preprocessing
    
    def __getitem__(self, i):
        
        # read images and masks
        image = cv2.cvtColor(cv2.imread(self.image_paths[i]), cv2.COLOR_BGR2RGB)
        mask = cv2.cvtColor(cv2.imread(self.mask_paths[i]), cv2.COLOR_BGR2RGB)

        # one-hot-encode the mask
        mask = one_hot_encode(mask, self.class_rgb_values).astype('float')
        
        # apply augmentations
        if self.augmentation:
            sample = self.augmentation(image=image, mask=mask)
            image, mask = sample['image'], sample['mask']
        
        # apply preprocessing
        if self.preprocessing:
            sample = self.preprocessing(image=image, mask=mask)
            image, mask = sample['image'], sample['mask']
            
        return image, mask#, self.image_paths[i]
        
    def __len__(self):
        # return length of 
        return len(self.image_paths)

# %% [markdown]
# #### Visualize Sample Image and Mask 📈

# %%
dataset = BuildingsDataset(x_train_dir, y_train_dir, class_rgb_values=select_class_rgb_values)
random_idx = random.randint(0, len(dataset)-1)
image, mask = dataset[1]

visualize(
    original_image = image,
    ground_truth_mask = colour_code_segmentation(reverse_one_hot(mask), select_class_rgb_values),
    one_hot_encoded_mask = reverse_one_hot(mask)
)

# %% [markdown]
# ### Defining Augmentations 🙃

# %%
def get_training_augmentation():
    train_transform = [    
        #album.augmentations.transforms.Sharpen( alpha = (0.2, 0.5),lightness = (0.5, 1.0),always_apply = True,p = 0.5,),
        album.RandomCrop(height=random_crop_size, width=random_crop_size, always_apply=True),
        album.OneOf(
            [
                album.HorizontalFlip(p=1),
                album.VerticalFlip(p=1),
                album.RandomRotate90(p=1),
            ],
            p=0.75,
        ),
    ]
    return album.Compose(train_transform)


def get_validation_augmentation():   
    # Add sufficient padding to ensure image is divisible by 32
    test_transform = [
        #album.PadIfNeeded(min_height=1536, min_width=1536, always_apply=True, border_mode=0),
        album.PadIfNeeded(min_height=15, min_width=15, always_apply=True, border_mode=0),
    ]
    return album.Compose(test_transform)


def to_tensor(x, **kwargs):
    #x = adjust_sharpness(Image.fromarray(np.uint8(x)), 5)
    return x.transpose(2, 0, 1).astype('float32')


def get_preprocessing(preprocessing_fn=None):
    """Construct preprocessing transform    
    Args:
        preprocessing_fn (callable): data normalization function 
            (can be specific for each pretrained neural network)
    Return:
        transform: albumentations.Compose
    """   
    _transform = []
    if preprocessing_fn:
        _transform.append(album.Lambda(image=preprocessing_fn))
    _transform.append(album.Lambda(image=to_tensor, mask=to_tensor))
        
    return album.Compose(_transform)

# %% [markdown]
# #### Visualize Augmented Images & Masks

# %%
augmented_dataset = BuildingsDataset(
    x_train_dir, y_train_dir, 
    augmentation=get_training_augmentation(),
    class_rgb_values=select_class_rgb_values,
)

random_idx = random.randint(0, len(augmented_dataset)-1)

# Different augmentations on a random image/mask pair (256*256 crop)
for i in range(3):
    image, mask = augmented_dataset[random_idx]
    visualize(
        original_image = image,
        ground_truth_mask = colour_code_segmentation(reverse_one_hot(mask), select_class_rgb_values),
        one_hot_encoded_mask = reverse_one_hot(mask)
    )

# %% [markdown]
# ## Training UNet with Pretrained ResNet50 Encoder

# %% [markdown]
# <h3><center>UNet Model Architecture</center></h3>
# <img src="https://miro.medium.com/max/2824/1*f7YOaE4TWubwaFF7Z1fzNw.png" width="750" height="750"/>
# <h4><center><a href="https://arxiv.org/abs/1505.04597">Image Courtesy: UNet [Ronneberger et al.]</a></center></h4>

# %% [markdown]
# ### Model Definition

# %%
ENCODER = 'resnet50'
ENCODER_WEIGHTS = 'imagenet'
CLASSES = class_names
ACTIVATION = 'sigmoid' # could be None for logits or 'softmax2d' for multiclass segmentation

# create segmentation model with pretrained encoder
model = smp.Unet(
    encoder_name=ENCODER, 
    encoder_weights=ENCODER_WEIGHTS, 
    classes=len(CLASSES), 
    activation=ACTIVATION,
)

preprocessing_fn = smp.encoders.get_preprocessing_fn(ENCODER, ENCODER_WEIGHTS)

# %% [markdown]
# #### Get Train / Val DataLoaders

# %%
# Get train and val dataset instances
train_dataset = BuildingsDataset(
    x_train_dir, y_train_dir, 
    augmentation=get_training_augmentation(),
    preprocessing=get_preprocessing(preprocessing_fn),
    class_rgb_values=select_class_rgb_values,   
)

valid_dataset = BuildingsDataset(
    x_valid_dir, y_valid_dir, 
    augmentation=get_training_augmentation(),
    preprocessing=get_preprocessing(preprocessing_fn),
    class_rgb_values=select_class_rgb_values, 
    
    # x_valid_dir, y_valid_dir, 
    # augmentation=get_validation_augmentation(), 
    # preprocessing=get_preprocessing(preprocessing_fn),
    # class_rgb_values=select_class_rgb_values,    
)

# Get train and val data loaders
train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True, num_workers=12)
valid_loader = DataLoader(valid_dataset, batch_size=1, shuffle=False, num_workers=4)

# %% [markdown]
# #### Set Hyperparams

# %%
# Set flag to train the model or not. If set to 'False', only prediction is performed (using an older model checkpoint)
TRAINING = True

# Set num of epochs
EPOCHS = 1000

# Set device: `cuda` or `cpu`
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

loss = utils.losses.BCELoss() 
metrics = [
utils.metrics.IoU(threshold=0.2),
utils.metrics.Fscore(),
utils.metrics.Recall(),
utils.metrics.Precision(),
]

# define optimizer
optimizer = torch.optim.Adam([ 
    dict(params=model.parameters(), lr=0.0001),
])

# define learning rate scheduler (not used in this NB)
lr_scheduler = torch.optim.lr_scheduler.CosineAnnealingWarmRestarts(
    optimizer, T_0=1, T_mult=2, eta_min=5e-5,
)
try:
    # load best saved model checkpoint from previous commit (if present)
    
    if os.path.exists(os.path.join(DATA_DIR,'best_model.pth')):
        print('load model')
        model = torch.load(os.path.join(DATA_DIR,'best_model.pth'), map_location=DEVICE)
    else:
        print('load model failed. check path or train from scratch.')
except:
    print('train from scatch')
# Out:
# load model

# %%
#train_epoch = smp.utils.train.TrainEpoch(
train_epoch = utils.train.TrainEpoch(
    model, 
    loss=loss, 
    metrics=metrics, 
    optimizer=optimizer,
    device=DEVICE,
    verbose=True,
)

valid_epoch = utils.train.ValidEpoch(
    model, 
    loss=loss, 
    metrics=metrics, 
    device=DEVICE,
    verbose=True,
)

# %% [markdown]
# ### Training UNet

# %% [markdown]
# ### Epoch:10 Samples:150 Time:27min Device: CPU
# ### Epoch:10 Samples:2000 Time:12min Device: GPU

# %%
# %%time
def early_stopping(t_score, v_score, v, n = 5):
    if v_score > t_score:
        v += 1
        if v > n:
            v = -1
    return v

if TRAINING:

    best_iou_score = 0.0
    train_logs_list, valid_logs_list = [], []
    v = 0

    for i in range(0, EPOCHS):

        # Perform training & validation
        print('\nEpoch: {}'.format(i))
        train_logs = train_epoch.run(train_loader)
        valid_logs = valid_epoch.run(valid_loader)
        train_logs_list.append(train_logs)
        valid_logs_list.append(valid_logs)

        # Save model if a better val IoU score is obtained
        if best_iou_score < valid_logs['iou_score']:
            best_iou_score = valid_logs['iou_score']
            torch.save(model, os.path.join(DATA_DIR,'best_model_u.pth'))
            print('Model saved!')
        
        # v = early_stopping(train_logs['iou_score'], valid_logs['iou_score'], v)
        # if v < 0:
        #     print('Early stopping!')
        #     break;
# Out:
# Epoch: 0
# train: 100%|██████████| 17/17 [00:02<00:00,  7.01it/s, bce_loss - 0.3815, iou_score - 0.6923, fscore - 0.8343, recall - 0.8542, precision - 0.8154]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.19it/s, bce_loss - 0.3814, iou_score - 0.6837, fscore - 0.831, recall - 0.8605, precision - 0.8053]
# Model saved!
#
# Epoch: 1
# train: 100%|██████████| 17/17 [00:02<00:00,  8.07it/s, bce_loss - 0.4162, iou_score - 0.6798, fscore - 0.823, recall - 0.8415, precision - 0.8054]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.35it/s, bce_loss - 0.3887, iou_score - 0.6853, fscore - 0.8286, recall - 0.8574, precision - 0.8034]
# Model saved!
#
# Epoch: 2
# train: 100%|██████████| 17/17 [00:02<00:00,  7.93it/s, bce_loss - 0.3948, iou_score - 0.6852, fscore - 0.8286, recall - 0.8471, precision - 0.811]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.57it/s, bce_loss - 0.3899, iou_score - 0.6828, fscore - 0.8292, recall - 0.8581, precision - 0.8041]
#
# Epoch: 3
# train: 100%|██████████| 17/17 [00:02<00:00,  7.99it/s, bce_loss - 0.3939, iou_score - 0.6851, fscore - 0.8298, recall - 0.8495, precision - 0.8111]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.19it/s, bce_loss - 0.3937, iou_score - 0.6842, fscore - 0.8278, recall - 0.8577, precision - 0.8018]
#
# Epoch: 4
# train: 100%|██████████| 17/17 [00:02<00:00,  7.83it/s, bce_loss - 0.4009, iou_score - 0.6811, fscore - 0.8252, recall - 0.8459, precision - 0.8057]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.55it/s, bce_loss - 0.3922, iou_score - 0.6834, fscore - 0.8274, recall - 0.8568, precision - 0.8017]
#
# Epoch: 5
# train: 100%|██████████| 17/17 [00:02<00:00,  7.95it/s, bce_loss - 0.3926, iou_score - 0.6875, fscore - 0.8306, recall - 0.8503, precision - 0.8119]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.61it/s, bce_loss - 0.3957, iou_score - 0.6805, fscore - 0.8259, recall - 0.8552, precision - 0.8004]
#
# Epoch: 6
# train: 100%|██████████| 17/17 [00:02<00:00,  7.89it/s, bce_loss - 0.3793, iou_score - 0.6914, fscore - 0.8361, recall - 0.8552, precision - 0.8179]
# valid: 100%|██████████| 114/114 [00:01<00:00, 64.97it/s, bce_loss - 0.3908, iou_score - 0.681, fscore - 0.8282, recall - 0.8581, precision - 0.8021]
#
# Epoch: 7
# train: 100%|██████████| 17/17 [00:02<00:00,  7.76it/s, bce_loss - 0.3919, iou_score - 0.6851, fscore - 0.83, recall - 0.8502, precision - 0.8107]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.64it/s, bce_loss - 0.3922, iou_score - 0.6853, fscore - 0.8305, recall - 0.8602, precision - 0.8046]
#
# Epoch: 8
# train: 100%|██████████| 17/17 [00:02<00:00,  7.91it/s, bce_loss - 0.4144, iou_score - 0.6807, fscore - 0.8244, recall - 0.8433, precision - 0.8064]
# valid: 100%|██████████| 114/114 [00:01<00:00, 64.96it/s, bce_loss - 0.4118, iou_score - 0.6795, fscore - 0.822, recall - 0.8512, precision - 0.7966]
#
# Epoch: 9
# train: 100%|██████████| 17/17 [00:02<00:00,  7.68it/s, bce_loss - 0.3971, iou_score - 0.6844, fscore - 0.8286, recall - 0.8493, precision - 0.8089]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.56it/s, bce_loss - 0.3934, iou_score - 0.685, fscore - 0.826, recall - 0.8553, precision - 0.8005]
#
# Epoch: 10
# train: 100%|██████████| 17/17 [00:02<00:00,  7.84it/s, bce_loss - 0.4042, iou_score - 0.6821, fscore - 0.8265, recall - 0.8465, precision - 0.8075]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.50it/s, bce_loss - 0.394, iou_score - 0.6797, fscore - 0.8253, recall - 0.8548, precision - 0.7996]
#
# Epoch: 11
# train: 100%|██████████| 17/17 [00:02<00:00,  7.90it/s, bce_loss - 0.3935, iou_score - 0.6869, fscore - 0.8308, recall - 0.8506, precision - 0.8119]
# valid: 100%|██████████| 114/114 [00:01<00:00, 64.43it/s, bce_loss - 0.3829, iou_score - 0.6849, fscore - 0.8291, recall - 0.8586, precision - 0.8035]
#
# Epoch: 12
# train: 100%|██████████| 17/17 [00:02<00:00,  7.80it/s, bce_loss - 0.4021, iou_score - 0.6821, fscore - 0.8266, recall - 0.8475, precision - 0.8068]
# valid: 100%|██████████| 114/114 [00:01<00:00, 64.82it/s, bce_loss - 0.4001, iou_score - 0.6873, fscore - 0.8295, recall - 0.8588, precision - 0.8039]
# Model saved!
#
# Epoch: 13
# train: 100%|██████████| 17/17 [00:02<00:00,  7.85it/s, bce_loss - 0.392, iou_score - 0.6865, fscore - 0.8314, recall - 0.8505, precision - 0.8132]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.34it/s, bce_loss - 0.3943, iou_score - 0.684, fscore - 0.8256, recall - 0.8549, precision - 0.8]
#
# Epoch: 14
# train: 100%|██████████| 17/17 [00:02<00:00,  7.87it/s, bce_loss - 0.3806, iou_score - 0.6898, fscore - 0.8326, recall - 0.8521, precision - 0.8141]
# valid: 100%|██████████| 114/114 [00:01<00:00, 64.91it/s, bce_loss - 0.3908, iou_score - 0.6797, fscore - 0.8275, recall - 0.8569, precision - 0.8019]
#
# Epoch: 15
# train: 100%|██████████| 17/17 [00:02<00:00,  7.88it/s, bce_loss - 0.3892, iou_score - 0.6886, fscore - 0.8316, recall - 0.8513, precision - 0.8128]
# valid: 100%|██████████| 114/114 [00:01<00:00, 64.57it/s, bce_loss - 0.3794, iou_score - 0.6898, fscore - 0.8349, recall - 0.8646, precision - 0.8091]
# Model saved!
#
# Epoch: 16
# train: 100%|██████████| 17/17 [00:02<00:00,  7.95it/s, bce_loss - 0.3957, iou_score - 0.6851, fscore - 0.8284, recall - 0.8486, precision - 0.8092]
# valid: 100%|██████████| 114/114 [00:01<00:00, 63.89it/s, bce_loss - 0.383, iou_score - 0.6871, fscore - 0.8344, recall - 0.8641, precision - 0.8086]
#
# Epoch: 17
# train: 100%|██████████| 17/17 [00:02<00:00,  7.68it/s, bce_loss - 0.3914, iou_score - 0.6881, fscore - 0.8312, recall - 0.8513, precision - 0.8122]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.19it/s, bce_loss - 0.4017, iou_score - 0.6792, fscore - 0.8245, recall - 0.8537, precision - 0.799]
#
# Epoch: 18
# train: 100%|██████████| 17/17 [00:02<00:00,  7.90it/s, bce_loss - 0.401, iou_score - 0.6817, fscore - 0.826, recall - 0.8449, precision - 0.808]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.17it/s, bce_loss - 0.4031, iou_score - 0.6798, fscore - 0.8243, recall - 0.8537, precision - 0.7987]
#
# Epoch: 19
# train: 100%|██████████| 17/17 [00:02<00:00,  7.82it/s, bce_loss - 0.414, iou_score - 0.6791, fscore - 0.8224, recall - 0.8415, precision - 0.8042]
# valid: 100%|██████████| 114/114 [00:01<00:00, 64.60it/s, bce_loss - 0.3918, iou_score - 0.6872, fscore - 0.8289, recall - 0.8586, precision - 0.803]
#
# Epoch: 20
# train: 100%|██████████| 17/17 [00:02<00:00,  7.82it/s, bce_loss - 0.4011, iou_score - 0.6864, fscore - 0.829, recall - 0.849, precision - 0.81]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.97it/s, bce_loss - 0.3805, iou_score - 0.6899, fscore - 0.8334, recall - 0.8627, precision - 0.8079]
# Model saved!
#
# Epoch: 21
# train: 100%|██████████| 17/17 [00:02<00:00,  7.79it/s, bce_loss - 0.4041, iou_score - 0.684, fscore - 0.8259, recall - 0.8452, precision - 0.8075]
# valid: 100%|██████████| 114/114 [00:01<00:00, 64.57it/s, bce_loss - 0.3842, iou_score - 0.6871, fscore - 0.8302, recall - 0.8593, precision - 0.8048]
#
# Epoch: 22
# train: 100%|██████████| 17/17 [00:02<00:00,  7.69it/s, bce_loss - 0.3889, iou_score - 0.6868, fscore - 0.8312, recall - 0.8515, precision - 0.8119]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.15it/s, bce_loss - 0.3903, iou_score - 0.684, fscore - 0.8298, recall - 0.859, precision - 0.8043]
#
# Epoch: 23
# train: 100%|██████████| 17/17 [00:02<00:00,  7.73it/s, bce_loss - 0.4042, iou_score - 0.6835, fscore - 0.8265, recall - 0.8456, precision - 0.8083]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.36it/s, bce_loss - 0.4195, iou_score - 0.6767, fscore - 0.8181, recall - 0.8473, precision - 0.7928]
#
# Epoch: 24
# train: 100%|██████████| 17/17 [00:02<00:00,  7.61it/s, bce_loss - 0.3943, iou_score - 0.6852, fscore - 0.8285, recall - 0.8473, precision - 0.8106]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.80it/s, bce_loss - 0.3913, iou_score - 0.6838, fscore - 0.8268, recall - 0.8564, precision - 0.8011]
#
# Epoch: 25
# train: 100%|██████████| 17/17 [00:02<00:00,  7.70it/s, bce_loss - 0.3956, iou_score - 0.6844, fscore - 0.8283, recall - 0.8478, precision - 0.8098]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.64it/s, bce_loss - 0.3965, iou_score - 0.6831, fscore - 0.8269, recall - 0.8564, precision - 0.8013]
#
# Epoch: 26
# train: 100%|██████████| 17/17 [00:02<00:00,  7.75it/s, bce_loss - 0.3905, iou_score - 0.6876, fscore - 0.8319, recall - 0.8511, precision - 0.8137]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.36it/s, bce_loss - 0.4054, iou_score - 0.6794, fscore - 0.8214, recall - 0.8507, precision - 0.7959]
#
# Epoch: 27
# train: 100%|██████████| 17/17 [00:02<00:00,  7.87it/s, bce_loss - 0.3924, iou_score - 0.6863, fscore - 0.8303, recall - 0.8497, precision - 0.8119]
# valid: 100%|██████████| 114/114 [00:01<00:00, 64.91it/s, bce_loss - 0.389, iou_score - 0.6828, fscore - 0.8293, recall - 0.8587, precision - 0.8036]
#
# Epoch: 28
# train: 100%|██████████| 17/17 [00:02<00:00,  7.80it/s, bce_loss - 0.3923, iou_score - 0.6854, fscore - 0.8292, recall - 0.8479, precision - 0.8114]
# valid: 100%|██████████| 114/114 [00:01<00:00, 64.73it/s, bce_loss - 0.4138, iou_score - 0.6797, fscore - 0.8209, recall - 0.8499, precision - 0.7956]
#
# Epoch: 29
# train: 100%|██████████| 17/17 [00:02<00:00,  7.73it/s, bce_loss - 0.3827, iou_score - 0.6893, fscore - 0.8329, recall - 0.8522, precision - 0.8146]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.29it/s, bce_loss - 0.3904, iou_score - 0.6841, fscore - 0.8269, recall - 0.8558, precision - 0.8017]
#
# Epoch: 30
# train: 100%|██████████| 17/17 [00:02<00:00,  7.80it/s, bce_loss - 0.3884, iou_score - 0.6864, fscore - 0.8302, recall - 0.8492, precision - 0.8122]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.57it/s, bce_loss - 0.3979, iou_score - 0.6858, fscore - 0.8281, recall - 0.8572, precision - 0.8027]
#
# Epoch: 31
# train: 100%|██████████| 17/17 [00:02<00:00,  7.68it/s, bce_loss - 0.4048, iou_score - 0.682, fscore - 0.8255, recall - 0.8461, precision - 0.8059]
# valid: 100%|██████████| 114/114 [00:01<00:00, 64.68it/s, bce_loss - 0.3998, iou_score - 0.6846, fscore - 0.8273, recall - 0.8568, precision - 0.8016]
#
# Epoch: 32
# train: 100%|██████████| 17/17 [00:02<00:00,  7.46it/s, bce_loss - 0.4269, iou_score - 0.6785, fscore - 0.823, recall - 0.8423, precision - 0.8046]
# valid: 100%|██████████| 114/114 [00:01<00:00, 66.19it/s, bce_loss - 0.3973, iou_score - 0.6831, fscore - 0.8263, recall - 0.8555, precision - 0.801]
#
# Epoch: 33
# train: 100%|██████████| 17/17 [00:02<00:00,  7.23it/s, bce_loss - 0.3902, iou_score - 0.6906, fscore - 0.832, recall - 0.8513, precision - 0.8137]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.34it/s, bce_loss - 0.392, iou_score - 0.6841, fscore - 0.828, recall - 0.8573, precision - 0.8026]
#
# Epoch: 34
# train: 100%|██████████| 17/17 [00:02<00:00,  7.87it/s, bce_loss - 0.3799, iou_score - 0.6893, fscore - 0.8327, recall - 0.8524, precision - 0.8139]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.17it/s, bce_loss - 0.3897, iou_score - 0.6864, fscore - 0.8283, recall - 0.8572, precision - 0.8031]
#
# Epoch: 35
# train: 100%|██████████| 17/17 [00:02<00:00,  7.66it/s, bce_loss - 0.3977, iou_score - 0.6872, fscore - 0.8308, recall - 0.8496, precision - 0.813]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.15it/s, bce_loss - 0.401, iou_score - 0.6826, fscore - 0.8262, recall - 0.8554, precision - 0.8008]
#
# Epoch: 36
# train: 100%|██████████| 17/17 [00:02<00:00,  7.75it/s, bce_loss - 0.4008, iou_score - 0.6809, fscore - 0.8269, recall - 0.8465, precision - 0.8083]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.75it/s, bce_loss - 0.3876, iou_score - 0.6848, fscore - 0.832, recall - 0.8616, precision - 0.8062]
#
# Epoch: 37
# train: 100%|██████████| 17/17 [00:02<00:00,  7.76it/s, bce_loss - 0.4086, iou_score - 0.6801, fscore - 0.824, recall - 0.8437, precision - 0.8053]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.53it/s, bce_loss - 0.3958, iou_score - 0.6828, fscore - 0.8265, recall - 0.8562, precision - 0.8006]
#
# Epoch: 38
# train: 100%|██████████| 17/17 [00:02<00:00,  7.68it/s, bce_loss - 0.3831, iou_score - 0.6896, fscore - 0.8339, recall - 0.8546, precision - 0.8144]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.04it/s, bce_loss - 0.385, iou_score - 0.6844, fscore - 0.8296, recall - 0.8589, precision - 0.804]
#
# Epoch: 39
# train: 100%|██████████| 17/17 [00:02<00:00,  7.67it/s, bce_loss - 0.3832, iou_score - 0.6931, fscore - 0.8346, recall - 0.8531, precision - 0.817]
# valid: 100%|██████████| 114/114 [00:01<00:00, 64.21it/s, bce_loss - 0.3961, iou_score - 0.6796, fscore - 0.8246, recall - 0.8532, precision - 0.7996]
#
# Epoch: 40
# train: 100%|██████████| 17/17 [00:02<00:00,  7.75it/s, bce_loss - 0.404, iou_score - 0.6837, fscore - 0.8271, recall - 0.848, precision - 0.8072]
# valid: 100%|██████████| 114/114 [00:01<00:00, 64.55it/s, bce_loss - 0.4066, iou_score - 0.6799, fscore - 0.8213, recall - 0.8509, precision - 0.7956]
#
# Epoch: 41
# train: 100%|██████████| 17/17 [00:02<00:00,  7.83it/s, bce_loss - 0.3938, iou_score - 0.6865, fscore - 0.8304, recall - 0.8503, precision - 0.8115]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.53it/s, bce_loss - 0.3919, iou_score - 0.6827, fscore - 0.8282, recall - 0.8575, precision - 0.8027]
#
# Epoch: 42
# train: 100%|██████████| 17/17 [00:02<00:00,  7.65it/s, bce_loss - 0.4094, iou_score - 0.6805, fscore - 0.8238, recall - 0.8443, precision - 0.8044]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.49it/s, bce_loss - 0.3951, iou_score - 0.6791, fscore - 0.8245, recall - 0.854, precision - 0.7987]
#
# Epoch: 43
# train: 100%|██████████| 17/17 [00:02<00:00,  7.60it/s, bce_loss - 0.399, iou_score - 0.6836, fscore - 0.8277, recall - 0.8483, precision - 0.8082]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.29it/s, bce_loss - 0.3955, iou_score - 0.6835, fscore - 0.829, recall - 0.8589, precision - 0.803]
#
# Epoch: 44
# train: 100%|██████████| 17/17 [00:02<00:00,  7.71it/s, bce_loss - 0.3868, iou_score - 0.6841, fscore - 0.8275, recall - 0.8482, precision - 0.8078]
# valid: 100%|██████████| 114/114 [00:01<00:00, 64.64it/s, bce_loss - 0.3943, iou_score - 0.6833, fscore - 0.8284, recall - 0.8578, precision - 0.8027]
#
# Epoch: 45
# train: 100%|██████████| 17/17 [00:02<00:00,  7.82it/s, bce_loss - 0.3985, iou_score - 0.6832, fscore - 0.8276, recall - 0.8479, precision - 0.8083]
# valid: 100%|██████████| 114/114 [00:01<00:00, 64.51it/s, bce_loss - 0.4025, iou_score - 0.681, fscore - 0.8256, recall - 0.8554, precision - 0.7997]
#
# Epoch: 46
# train: 100%|██████████| 17/17 [00:02<00:00,  7.81it/s, bce_loss - 0.3996, iou_score - 0.6819, fscore - 0.8274, recall - 0.8473, precision - 0.8085]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.16it/s, bce_loss - 0.3924, iou_score - 0.6843, fscore - 0.8272, recall - 0.8568, precision - 0.8015]
#
# Epoch: 47
# train: 100%|██████████| 17/17 [00:02<00:00,  7.72it/s, bce_loss - 0.3994, iou_score - 0.6846, fscore - 0.8272, recall - 0.8467, precision - 0.8086]
# valid: 100%|██████████| 114/114 [00:01<00:00, 64.91it/s, bce_loss - 0.4012, iou_score - 0.682, fscore - 0.8271, recall - 0.8567, precision - 0.8013]
#
# Epoch: 48
# train: 100%|██████████| 17/17 [00:02<00:00,  7.80it/s, bce_loss - 0.383, iou_score - 0.6905, fscore - 0.8334, recall - 0.8525, precision - 0.8153]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.36it/s, bce_loss - 0.4093, iou_score - 0.681, fscore - 0.8217, recall - 0.8509, precision - 0.7962]
#
# Epoch: 49
# train: 100%|██████████| 17/17 [00:02<00:00,  7.65it/s, bce_loss - 0.4042, iou_score - 0.6821, fscore - 0.8266, recall - 0.8466, precision - 0.8075]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.00it/s, bce_loss - 0.3846, iou_score - 0.6853, fscore - 0.8327, recall - 0.8625, precision - 0.8068]
#
# Epoch: 50
# train: 100%|██████████| 17/17 [00:02<00:00,  7.61it/s, bce_loss - 0.3848, iou_score - 0.69, fscore - 0.8347, recall - 0.8536, precision - 0.8167]
# valid: 100%|██████████| 114/114 [00:01<00:00, 64.82it/s, bce_loss - 0.4027, iou_score - 0.6791, fscore - 0.8249, recall - 0.8538, precision - 0.7997]
#
# Epoch: 51
# train: 100%|██████████| 17/17 [00:02<00:00,  7.66it/s, bce_loss - 0.3826, iou_score - 0.6903, fscore - 0.8352, recall - 0.8549, precision - 0.8164]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.75it/s, bce_loss - 0.3885, iou_score - 0.682, fscore - 0.8252, recall - 0.8546, precision - 0.7995]
#
# Epoch: 52
# train: 100%|██████████| 17/17 [00:02<00:00,  7.74it/s, bce_loss - 0.409, iou_score - 0.6825, fscore - 0.8262, recall - 0.8469, precision - 0.8067]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.28it/s, bce_loss - 0.4007, iou_score - 0.682, fscore - 0.8257, recall - 0.8551, precision - 0.8]
#
# Epoch: 53
# train: 100%|██████████| 17/17 [00:02<00:00,  7.72it/s, bce_loss - 0.4046, iou_score - 0.6791, fscore - 0.8246, recall - 0.8442, precision - 0.806]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.29it/s, bce_loss - 0.3971, iou_score - 0.6822, fscore - 0.8253, recall - 0.854, precision - 0.8002]
#
# Epoch: 54
# train: 100%|██████████| 17/17 [00:02<00:00,  7.60it/s, bce_loss - 0.4052, iou_score - 0.6816, fscore - 0.8269, recall - 0.8475, precision - 0.8074]
# valid: 100%|██████████| 114/114 [00:01<00:00, 64.65it/s, bce_loss - 0.3925, iou_score - 0.6827, fscore - 0.827, recall - 0.8565, precision - 0.8013]
#
# Epoch: 55
# train: 100%|██████████| 17/17 [00:02<00:00,  7.69it/s, bce_loss - 0.3858, iou_score - 0.6865, fscore - 0.8297, recall - 0.8511, precision - 0.8095]
# valid: 100%|██████████| 114/114 [00:01<00:00, 64.69it/s, bce_loss - 0.3988, iou_score - 0.682, fscore - 0.8255, recall - 0.8549, precision - 0.7999]
#
# Epoch: 56
# train: 100%|██████████| 17/17 [00:02<00:00,  7.69it/s, bce_loss - 0.4141, iou_score - 0.6795, fscore - 0.8234, recall - 0.844, precision - 0.8039]
# valid: 100%|██████████| 114/114 [00:01<00:00, 64.00it/s, bce_loss - 0.3901, iou_score - 0.6822, fscore - 0.8292, recall - 0.8589, precision - 0.8033]
#
# Epoch: 57
# train: 100%|██████████| 17/17 [00:02<00:00,  7.78it/s, bce_loss - 0.3996, iou_score - 0.6838, fscore - 0.8301, recall - 0.8504, precision - 0.8108]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.23it/s, bce_loss - 0.3936, iou_score - 0.6812, fscore - 0.8246, recall - 0.8538, precision - 0.7992]
#
# Epoch: 58
# train: 100%|██████████| 17/17 [00:02<00:00,  7.68it/s, bce_loss - 0.4002, iou_score - 0.6839, fscore - 0.826, recall - 0.8457, precision - 0.8073]
# valid: 100%|██████████| 114/114 [00:01<00:00, 64.88it/s, bce_loss - 0.3861, iou_score - 0.6859, fscore - 0.8298, recall - 0.8594, precision - 0.804]
#
# Epoch: 59
# train: 100%|██████████| 17/17 [00:02<00:00,  7.67it/s, bce_loss - 0.3834, iou_score - 0.6895, fscore - 0.8317, recall - 0.8507, precision - 0.8137]
# valid: 100%|██████████| 114/114 [00:01<00:00, 64.92it/s, bce_loss - 0.4003, iou_score - 0.6839, fscore - 0.825, recall - 0.854, precision - 0.7997]
#
# Epoch: 60
# train: 100%|██████████| 17/17 [00:02<00:00,  7.67it/s, bce_loss - 0.4132, iou_score - 0.6798, fscore - 0.8234, recall - 0.8435, precision - 0.8042]
# valid: 100%|██████████| 114/114 [00:01<00:00, 64.74it/s, bce_loss - 0.3982, iou_score - 0.6786, fscore - 0.8237, recall - 0.8533, precision - 0.798]
#
# Epoch: 61
# train: 100%|██████████| 17/17 [00:02<00:00,  7.75it/s, bce_loss - 0.4029, iou_score - 0.6859, fscore - 0.8309, recall - 0.8511, precision - 0.8117]
# valid: 100%|██████████| 114/114 [00:01<00:00, 64.50it/s, bce_loss - 0.3981, iou_score - 0.6827, fscore - 0.8213, recall - 0.8499, precision - 0.7964]
#
# Epoch: 62
# train: 100%|██████████| 17/17 [00:02<00:00,  7.56it/s, bce_loss - 0.3821, iou_score - 0.689, fscore - 0.8335, recall - 0.8529, precision - 0.815]
# valid: 100%|██████████| 114/114 [00:01<00:00, 64.70it/s, bce_loss - 0.3909, iou_score - 0.682, fscore - 0.8288, recall - 0.8583, precision - 0.8031]
#
# Epoch: 63
# train: 100%|██████████| 17/17 [00:02<00:00,  7.65it/s, bce_loss - 0.4107, iou_score - 0.6805, fscore - 0.8266, recall - 0.8476, precision - 0.8068]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.76it/s, bce_loss - 0.3944, iou_score - 0.6831, fscore - 0.826, recall - 0.8557, precision - 0.8002]
#
# Epoch: 64
# train: 100%|██████████| 17/17 [00:02<00:00,  7.67it/s, bce_loss - 0.4026, iou_score - 0.6825, fscore - 0.8243, recall - 0.843, precision - 0.8064]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.33it/s, bce_loss - 0.4032, iou_score - 0.6794, fscore - 0.8223, recall - 0.8513, precision - 0.797]
#
# Epoch: 65
# train: 100%|██████████| 17/17 [00:02<00:00,  7.67it/s, bce_loss - 0.4092, iou_score - 0.6822, fscore - 0.8273, recall - 0.848, precision - 0.8076]
# valid: 100%|██████████| 114/114 [00:01<00:00, 64.49it/s, bce_loss - 0.3921, iou_score - 0.6845, fscore - 0.8285, recall - 0.8583, precision - 0.8025]
#
# Epoch: 66
# train: 100%|██████████| 17/17 [00:02<00:00,  7.82it/s, bce_loss - 0.4002, iou_score - 0.6847, fscore - 0.8276, recall - 0.8471, precision - 0.8091]
# valid: 100%|██████████| 114/114 [00:01<00:00, 64.52it/s, bce_loss - 0.3929, iou_score - 0.6812, fscore - 0.826, recall - 0.855, precision - 0.8007]
#
# Epoch: 67
# train: 100%|██████████| 17/17 [00:02<00:00,  7.75it/s, bce_loss - 0.4124, iou_score - 0.6804, fscore - 0.8253, recall - 0.8457, precision - 0.8061]
# valid: 100%|██████████| 114/114 [00:01<00:00, 64.52it/s, bce_loss - 0.3824, iou_score - 0.6895, fscore - 0.8322, recall - 0.8617, precision - 0.8065]
#
# Epoch: 68
# train: 100%|██████████| 17/17 [00:02<00:00,  7.76it/s, bce_loss - 0.3904, iou_score - 0.6853, fscore - 0.83, recall - 0.8498, precision - 0.8111]
# valid: 100%|██████████| 114/114 [00:01<00:00, 64.83it/s, bce_loss - 0.3946, iou_score - 0.6794, fscore - 0.824, recall - 0.8532, precision - 0.7986]
#
# Epoch: 69
# train: 100%|██████████| 17/17 [00:02<00:00,  7.75it/s, bce_loss - 0.3968, iou_score - 0.685, fscore - 0.829, recall - 0.8498, precision - 0.8095]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.41it/s, bce_loss - 0.3891, iou_score - 0.6813, fscore - 0.8276, recall - 0.8576, precision - 0.8014]
#
# Epoch: 70
# train: 100%|██████████| 17/17 [00:02<00:00,  7.61it/s, bce_loss - 0.3944, iou_score - 0.6861, fscore - 0.8302, recall - 0.8498, precision - 0.8115]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.53it/s, bce_loss - 0.3983, iou_score - 0.6817, fscore - 0.8242, recall - 0.8533, precision - 0.7989]
#
# Epoch: 71
# train: 100%|██████████| 17/17 [00:02<00:00,  7.57it/s, bce_loss - 0.3945, iou_score - 0.6859, fscore - 0.8311, recall - 0.8505, precision - 0.8126]
# valid: 100%|██████████| 114/114 [00:01<00:00, 64.64it/s, bce_loss - 0.3938, iou_score - 0.6851, fscore - 0.8279, recall - 0.8574, precision - 0.8022]
#
# Epoch: 72
# train: 100%|██████████| 17/17 [00:02<00:00,  7.71it/s, bce_loss - 0.4072, iou_score - 0.6811, fscore - 0.825, recall - 0.8447, precision - 0.8063]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.92it/s, bce_loss - 0.4043, iou_score - 0.6837, fscore - 0.828, recall - 0.8571, precision - 0.8027]
#
# Epoch: 73
# train: 100%|██████████| 17/17 [00:02<00:00,  7.66it/s, bce_loss - 0.4066, iou_score - 0.6821, fscore - 0.8228, recall - 0.8428, precision - 0.8038]
# valid: 100%|██████████| 114/114 [00:01<00:00, 66.45it/s, bce_loss - 0.3865, iou_score - 0.6859, fscore - 0.8285, recall - 0.8579, precision - 0.8029]
#
# Epoch: 74
# train: 100%|██████████| 17/17 [00:02<00:00,  7.66it/s, bce_loss - 0.401, iou_score - 0.683, fscore - 0.8267, recall - 0.847, precision - 0.8074]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.29it/s, bce_loss - 0.393, iou_score - 0.6894, fscore - 0.8303, recall - 0.8597, precision - 0.8046]
#
# Epoch: 75
# train: 100%|██████████| 17/17 [00:02<00:00,  7.46it/s, bce_loss - 0.3786, iou_score - 0.691, fscore - 0.833, recall - 0.852, precision - 0.815]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.53it/s, bce_loss - 0.3985, iou_score - 0.6821, fscore - 0.8238, recall - 0.853, precision - 0.7984]
#
# Epoch: 76
# train: 100%|██████████| 17/17 [00:02<00:00,  7.59it/s, bce_loss - 0.384, iou_score - 0.6886, fscore - 0.833, recall - 0.853, precision - 0.814]
# valid: 100%|██████████| 114/114 [00:01<00:00, 64.79it/s, bce_loss - 0.3967, iou_score - 0.6799, fscore - 0.8242, recall - 0.8538, precision - 0.7984]
#
# Epoch: 77
# train: 100%|██████████| 17/17 [00:02<00:00,  7.45it/s, bce_loss - 0.3851, iou_score - 0.6887, fscore - 0.8314, recall - 0.8511, precision - 0.8127]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.51it/s, bce_loss - 0.382, iou_score - 0.6852, fscore - 0.8317, recall - 0.8613, precision - 0.8058]
#
# Epoch: 78
# train: 100%|██████████| 17/17 [00:02<00:00,  7.64it/s, bce_loss - 0.4056, iou_score - 0.6846, fscore - 0.8301, recall - 0.8493, precision - 0.8118]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.69it/s, bce_loss - 0.3954, iou_score - 0.6844, fscore - 0.8251, recall - 0.8539, precision - 0.8]
#
# Epoch: 79
# train: 100%|██████████| 17/17 [00:02<00:00,  7.64it/s, bce_loss - 0.4086, iou_score - 0.6785, fscore - 0.8227, recall - 0.8433, precision - 0.8033]
# valid: 100%|██████████| 114/114 [00:01<00:00, 64.57it/s, bce_loss - 0.3984, iou_score - 0.686, fscore - 0.8297, recall - 0.859, precision - 0.8042]
#
# Epoch: 80
# train: 100%|██████████| 17/17 [00:02<00:00,  7.52it/s, bce_loss - 0.3861, iou_score - 0.6903, fscore - 0.833, recall - 0.852, precision - 0.815]
# valid: 100%|██████████| 114/114 [00:01<00:00, 64.89it/s, bce_loss - 0.3917, iou_score - 0.683, fscore - 0.8292, recall - 0.8586, precision - 0.8036]
#
# Epoch: 81
# train: 100%|██████████| 17/17 [00:02<00:00,  7.64it/s, bce_loss - 0.3885, iou_score - 0.6901, fscore - 0.8326, recall - 0.8522, precision - 0.814]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.43it/s, bce_loss - 0.3912, iou_score - 0.6835, fscore - 0.8256, recall - 0.8547, precision - 0.8001]
#
# Epoch: 82
# train: 100%|██████████| 17/17 [00:02<00:00,  7.54it/s, bce_loss - 0.4024, iou_score - 0.6838, fscore - 0.8277, recall - 0.8479, precision - 0.8085]
# valid: 100%|██████████| 114/114 [00:01<00:00, 64.71it/s, bce_loss - 0.392, iou_score - 0.6821, fscore - 0.8293, recall - 0.8584, precision - 0.8038]
#
# Epoch: 83
# train: 100%|██████████| 17/17 [00:02<00:00,  7.67it/s, bce_loss - 0.39, iou_score - 0.6845, fscore - 0.8307, recall - 0.8514, precision - 0.8111]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.85it/s, bce_loss - 0.3795, iou_score - 0.6842, fscore - 0.8301, recall - 0.8597, precision - 0.8044]
#
# Epoch: 84
# train: 100%|██████████| 17/17 [00:02<00:00,  7.44it/s, bce_loss - 0.3851, iou_score - 0.6898, fscore - 0.8328, recall - 0.8528, precision - 0.8139]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.45it/s, bce_loss - 0.3912, iou_score - 0.6832, fscore - 0.8304, recall - 0.8599, precision - 0.8047]
#
# Epoch: 85
# train: 100%|██████████| 17/17 [00:02<00:00,  7.59it/s, bce_loss - 0.4006, iou_score - 0.6839, fscore - 0.8297, recall - 0.8507, precision - 0.8098]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.52it/s, bce_loss - 0.3839, iou_score - 0.687, fscore - 0.8298, recall - 0.8597, precision - 0.8038]
#
# Epoch: 86
# train: 100%|██████████| 17/17 [00:02<00:00,  7.55it/s, bce_loss - 0.3853, iou_score - 0.6873, fscore - 0.8314, recall - 0.851, precision - 0.8128]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.47it/s, bce_loss - 0.3944, iou_score - 0.6844, fscore - 0.8264, recall - 0.8558, precision - 0.8008]
#
# Epoch: 87
# train: 100%|██████████| 17/17 [00:02<00:00,  7.66it/s, bce_loss - 0.3927, iou_score - 0.6885, fscore - 0.8318, recall - 0.8516, precision - 0.813]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.20it/s, bce_loss - 0.382, iou_score - 0.6849, fscore - 0.83, recall - 0.86, precision - 0.804]
#
# Epoch: 88
# train: 100%|██████████| 17/17 [00:02<00:00,  7.54it/s, bce_loss - 0.3874, iou_score - 0.6877, fscore - 0.8329, recall - 0.8521, precision - 0.8147]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.62it/s, bce_loss - 0.3886, iou_score - 0.6813, fscore - 0.8288, recall - 0.8581, precision - 0.8033]
#
# Epoch: 89
# train: 100%|██████████| 17/17 [00:02<00:00,  7.52it/s, bce_loss - 0.3868, iou_score - 0.6873, fscore - 0.8304, recall - 0.8498, precision - 0.8119]
# valid: 100%|██████████| 114/114 [00:01<00:00, 64.65it/s, bce_loss - 0.3865, iou_score - 0.6833, fscore - 0.831, recall - 0.8605, precision - 0.8053]
#
# Epoch: 90
# train: 100%|██████████| 17/17 [00:02<00:00,  7.66it/s, bce_loss - 0.3841, iou_score - 0.6858, fscore - 0.8314, recall - 0.8521, precision - 0.8118]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.31it/s, bce_loss - 0.3905, iou_score - 0.6849, fscore - 0.8277, recall - 0.857, precision - 0.8022]
#
# Epoch: 91
# train: 100%|██████████| 17/17 [00:02<00:00,  7.62it/s, bce_loss - 0.3875, iou_score - 0.6874, fscore - 0.8304, recall - 0.85, precision - 0.8116]
# valid: 100%|██████████| 114/114 [00:01<00:00, 64.62it/s, bce_loss - 0.3848, iou_score - 0.6864, fscore - 0.8308, recall - 0.8603, precision - 0.8051]
#
# Epoch: 92
# train: 100%|██████████| 17/17 [00:02<00:00,  7.46it/s, bce_loss - 0.3904, iou_score - 0.6884, fscore - 0.8308, recall - 0.8496, precision - 0.813]
# valid: 100%|██████████| 114/114 [00:01<00:00, 64.87it/s, bce_loss - 0.387, iou_score - 0.6834, fscore - 0.8263, recall - 0.8551, precision - 0.8012]
#
# Epoch: 93
# train: 100%|██████████| 17/17 [00:02<00:00,  7.59it/s, bce_loss - 0.398, iou_score - 0.685, fscore - 0.8293, recall - 0.8488, precision - 0.8107]
# valid: 100%|██████████| 114/114 [00:01<00:00, 64.88it/s, bce_loss - 0.3942, iou_score - 0.6817, fscore - 0.8278, recall - 0.857, precision - 0.8023]
#
# Epoch: 94
# train: 100%|██████████| 17/17 [00:02<00:00,  7.59it/s, bce_loss - 0.4064, iou_score - 0.6794, fscore - 0.8233, recall - 0.844, precision - 0.8038]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.29it/s, bce_loss - 0.3899, iou_score - 0.6867, fscore - 0.8304, recall - 0.8594, precision - 0.805]
#
# Epoch: 95
# train: 100%|██████████| 17/17 [00:02<00:00,  7.57it/s, bce_loss - 0.3945, iou_score - 0.6869, fscore - 0.83, recall - 0.8493, precision - 0.8116]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.13it/s, bce_loss - 0.3948, iou_score - 0.68, fscore - 0.8267, recall - 0.8562, precision - 0.8009]
#
# Epoch: 96
# train: 100%|██████████| 17/17 [00:02<00:00,  7.48it/s, bce_loss - 0.402, iou_score - 0.6813, fscore - 0.8275, recall - 0.8465, precision - 0.8094]
# valid: 100%|██████████| 114/114 [00:01<00:00, 64.83it/s, bce_loss - 0.4018, iou_score - 0.6802, fscore - 0.8243, recall - 0.8537, precision - 0.7988]
#
# Epoch: 97
# train: 100%|██████████| 17/17 [00:02<00:00,  7.69it/s, bce_loss - 0.3942, iou_score - 0.6862, fscore - 0.8302, recall - 0.8496, precision - 0.8119]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.05it/s, bce_loss - 0.4027, iou_score - 0.6823, fscore - 0.8252, recall - 0.8546, precision - 0.7997]
#
# Epoch: 98
# train: 100%|██████████| 17/17 [00:02<00:00,  7.60it/s, bce_loss - 0.3957, iou_score - 0.6839, fscore - 0.8283, recall - 0.8478, precision - 0.8098]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.16it/s, bce_loss - 0.4034, iou_score - 0.678, fscore - 0.8221, recall - 0.8511, precision - 0.7968]
#
# Epoch: 99
# train: 100%|██████████| 17/17 [00:02<00:00,  7.46it/s, bce_loss - 0.4022, iou_score - 0.684, fscore - 0.8277, recall - 0.8475, precision - 0.8089]
# valid: 100%|██████████| 114/114 [00:01<00:00, 64.69it/s, bce_loss - 0.3872, iou_score - 0.6856, fscore - 0.8269, recall - 0.8561, precision - 0.8015]
#
# Epoch: 100
# train: 100%|██████████| 17/17 [00:02<00:00,  7.62it/s, bce_loss - 0.4007, iou_score - 0.68, fscore - 0.8256, recall - 0.8469, precision - 0.8057]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.20it/s, bce_loss - 0.3971, iou_score - 0.6826, fscore - 0.8263, recall - 0.8557, precision - 0.8007]
#
# Epoch: 101
# train: 100%|██████████| 17/17 [00:02<00:00,  7.67it/s, bce_loss - 0.3974, iou_score - 0.6847, fscore - 0.8285, recall - 0.8485, precision - 0.8095]
# valid: 100%|██████████| 114/114 [00:01<00:00, 64.85it/s, bce_loss - 0.3961, iou_score - 0.6831, fscore - 0.8246, recall - 0.8539, precision - 0.7991]
#
# Epoch: 102
# train: 100%|██████████| 17/17 [00:02<00:00,  7.59it/s, bce_loss - 0.3835, iou_score - 0.6856, fscore - 0.8312, recall - 0.8524, precision - 0.8111]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.16it/s, bce_loss - 0.3912, iou_score - 0.6804, fscore - 0.8269, recall - 0.8567, precision - 0.801]
#
# Epoch: 103
# train: 100%|██████████| 17/17 [00:02<00:00,  7.64it/s, bce_loss - 0.386, iou_score - 0.6862, fscore - 0.8298, recall - 0.8496, precision - 0.8111]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.49it/s, bce_loss - 0.3764, iou_score - 0.6869, fscore - 0.8323, recall - 0.8619, precision - 0.8065]
#
# Epoch: 104
# train: 100%|██████████| 17/17 [00:02<00:00,  7.52it/s, bce_loss - 0.3869, iou_score - 0.6888, fscore - 0.8318, recall - 0.8506, precision - 0.8139]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.57it/s, bce_loss - 0.3915, iou_score - 0.6833, fscore - 0.827, recall - 0.8561, precision - 0.8016]
#
# Epoch: 105
# train: 100%|██████████| 17/17 [00:02<00:00,  7.51it/s, bce_loss - 0.3821, iou_score - 0.6898, fscore - 0.8337, recall - 0.8539, precision - 0.8146]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.30it/s, bce_loss - 0.3929, iou_score - 0.6817, fscore - 0.8279, recall - 0.8574, precision - 0.8021]
#
# Epoch: 106
# train: 100%|██████████| 17/17 [00:02<00:00,  7.55it/s, bce_loss - 0.3971, iou_score - 0.6825, fscore - 0.8279, recall - 0.8498, precision - 0.8075]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.67it/s, bce_loss - 0.3929, iou_score - 0.6825, fscore - 0.8259, recall - 0.8555, precision - 0.8001]
#
# Epoch: 107
# train: 100%|██████████| 17/17 [00:02<00:00,  7.40it/s, bce_loss - 0.4032, iou_score - 0.682, fscore - 0.8264, recall - 0.8456, precision - 0.8082]
# valid: 100%|██████████| 114/114 [00:01<00:00, 64.70it/s, bce_loss - 0.4047, iou_score - 0.6811, fscore - 0.823, recall - 0.8523, precision - 0.7975]
#
# Epoch: 108
# train: 100%|██████████| 17/17 [00:02<00:00,  7.69it/s, bce_loss - 0.4043, iou_score - 0.6814, fscore - 0.8259, recall - 0.8462, precision - 0.8066]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.05it/s, bce_loss - 0.3982, iou_score - 0.6843, fscore - 0.8272, recall - 0.8565, precision - 0.8017]
#
# Epoch: 109
# train: 100%|██████████| 17/17 [00:02<00:00,  7.58it/s, bce_loss - 0.3776, iou_score - 0.6919, fscore - 0.8367, recall - 0.8556, precision - 0.8187]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.94it/s, bce_loss - 0.399, iou_score - 0.6815, fscore - 0.8272, recall - 0.8567, precision - 0.8015]
#
# Epoch: 110
# train: 100%|██████████| 17/17 [00:02<00:00,  7.58it/s, bce_loss - 0.3976, iou_score - 0.6854, fscore - 0.8313, recall - 0.8519, precision - 0.8116]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.39it/s, bce_loss - 0.3965, iou_score - 0.6822, fscore - 0.8255, recall - 0.8548, precision - 0.8]
#
# Epoch: 111
# train: 100%|██████████| 17/17 [00:02<00:00,  7.59it/s, bce_loss - 0.3969, iou_score - 0.6825, fscore - 0.8281, recall - 0.8484, precision - 0.8088]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.37it/s, bce_loss - 0.4062, iou_score - 0.6798, fscore - 0.8213, recall - 0.85, precision - 0.7962]
#
# Epoch: 112
# train: 100%|██████████| 17/17 [00:02<00:00,  7.61it/s, bce_loss - 0.4044, iou_score - 0.6802, fscore - 0.825, recall - 0.8439, precision - 0.807]
# valid: 100%|██████████| 114/114 [00:01<00:00, 64.88it/s, bce_loss - 0.3966, iou_score - 0.6823, fscore - 0.8282, recall - 0.8578, precision - 0.8024]
#
# Epoch: 113
# train: 100%|██████████| 17/17 [00:02<00:00,  7.59it/s, bce_loss - 0.3854, iou_score - 0.6889, fscore - 0.8335, recall - 0.8529, precision - 0.8151]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.34it/s, bce_loss - 0.399, iou_score - 0.681, fscore - 0.8246, recall - 0.8536, precision - 0.7994]
#
# Epoch: 114
# train: 100%|██████████| 17/17 [00:02<00:00,  7.38it/s, bce_loss - 0.3927, iou_score - 0.6891, fscore - 0.8324, recall - 0.8512, precision - 0.8144]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.66it/s, bce_loss - 0.4052, iou_score - 0.6798, fscore - 0.8226, recall - 0.8513, precision - 0.7976]
#
# Epoch: 115
# train: 100%|██████████| 17/17 [00:02<00:00,  7.57it/s, bce_loss - 0.3915, iou_score - 0.6839, fscore - 0.8302, recall - 0.8521, precision - 0.8096]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.29it/s, bce_loss - 0.4002, iou_score - 0.6818, fscore - 0.8263, recall - 0.8557, precision - 0.8006]
#
# Epoch: 116
# train: 100%|██████████| 17/17 [00:02<00:00,  7.55it/s, bce_loss - 0.3879, iou_score - 0.6858, fscore - 0.8312, recall - 0.8513, precision - 0.8121]
# valid: 100%|██████████| 114/114 [00:01<00:00, 64.67it/s, bce_loss - 0.3808, iou_score - 0.688, fscore - 0.8335, recall - 0.8634, precision - 0.8076]
#
# Epoch: 117
# train: 100%|██████████| 17/17 [00:02<00:00,  7.68it/s, bce_loss - 0.3905, iou_score - 0.6864, fscore - 0.831, recall - 0.8515, precision - 0.8117]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.20it/s, bce_loss - 0.3922, iou_score - 0.6848, fscore - 0.8291, recall - 0.8587, precision - 0.8034]
#
# Epoch: 118
# train: 100%|██████████| 17/17 [00:02<00:00,  7.66it/s, bce_loss - 0.4032, iou_score - 0.6828, fscore - 0.8268, recall - 0.8476, precision - 0.8072]
# valid: 100%|██████████| 114/114 [00:01<00:00, 64.79it/s, bce_loss - 0.4011, iou_score - 0.6832, fscore - 0.8262, recall - 0.8558, precision - 0.8004]
#
# Epoch: 119
# train: 100%|██████████| 17/17 [00:02<00:00,  7.62it/s, bce_loss - 0.3823, iou_score - 0.6878, fscore - 0.8335, recall - 0.8536, precision - 0.8144]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.31it/s, bce_loss - 0.3904, iou_score - 0.6853, fscore - 0.8331, recall - 0.863, precision - 0.807]
#
# Epoch: 120
# train: 100%|██████████| 17/17 [00:02<00:00,  7.58it/s, bce_loss - 0.3853, iou_score - 0.6892, fscore - 0.8324, recall - 0.8513, precision - 0.8144]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.83it/s, bce_loss - 0.3872, iou_score - 0.6815, fscore - 0.827, recall - 0.8561, precision - 0.8016]
#
# Epoch: 121
# train: 100%|██████████| 17/17 [00:02<00:00,  7.52it/s, bce_loss - 0.4245, iou_score - 0.6772, fscore - 0.8228, recall - 0.8429, precision - 0.8037]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.61it/s, bce_loss - 0.4081, iou_score - 0.6807, fscore - 0.8237, recall - 0.8532, precision - 0.7981]
#
# Epoch: 122
# train: 100%|██████████| 17/17 [00:02<00:00,  7.52it/s, bce_loss - 0.4012, iou_score - 0.6813, fscore - 0.8264, recall - 0.8468, precision - 0.8071]
# valid: 100%|██████████| 114/114 [00:01<00:00, 64.03it/s, bce_loss - 0.3911, iou_score - 0.6841, fscore - 0.8282, recall - 0.8578, precision - 0.8024]
#
# Epoch: 123
# train: 100%|██████████| 17/17 [00:02<00:00,  7.56it/s, bce_loss - 0.3846, iou_score - 0.6896, fscore - 0.8324, recall - 0.8513, precision - 0.8145]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.52it/s, bce_loss - 0.4076, iou_score - 0.6782, fscore - 0.8207, recall - 0.8494, precision - 0.7956]
#
# Epoch: 124
# train: 100%|██████████| 17/17 [00:02<00:00,  7.64it/s, bce_loss - 0.3991, iou_score - 0.6855, fscore - 0.8288, recall - 0.8485, precision - 0.81]
# valid: 100%|██████████| 114/114 [00:01<00:00, 64.99it/s, bce_loss - 0.3929, iou_score - 0.6836, fscore - 0.8282, recall - 0.8576, precision - 0.8025]
#
# Epoch: 125
# train: 100%|██████████| 17/17 [00:02<00:00,  7.58it/s, bce_loss - 0.3985, iou_score - 0.6847, fscore - 0.8282, recall - 0.8479, precision - 0.8095]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.27it/s, bce_loss - 0.3925, iou_score - 0.6832, fscore - 0.8275, recall - 0.8572, precision - 0.8016]
#
# Epoch: 126
# train: 100%|██████████| 17/17 [00:02<00:00,  7.55it/s, bce_loss - 0.3864, iou_score - 0.6874, fscore - 0.8316, recall - 0.8514, precision - 0.8128]
# valid: 100%|██████████| 114/114 [00:01<00:00, 64.69it/s, bce_loss - 0.3869, iou_score - 0.684, fscore - 0.8284, recall - 0.8578, precision - 0.8028]
#
# Epoch: 127
# train: 100%|██████████| 17/17 [00:02<00:00,  7.65it/s, bce_loss - 0.4104, iou_score - 0.6783, fscore - 0.8208, recall - 0.8397, precision - 0.803]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.52it/s, bce_loss - 0.4054, iou_score - 0.6838, fscore - 0.8261, recall - 0.8548, precision - 0.801]
#
# Epoch: 128
# train: 100%|██████████| 17/17 [00:02<00:00,  7.59it/s, bce_loss - 0.3827, iou_score - 0.6882, fscore - 0.8302, recall - 0.8495, precision - 0.8119]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.64it/s, bce_loss - 0.4008, iou_score - 0.6783, fscore - 0.8241, recall - 0.8531, precision - 0.7988]
#
# Epoch: 129
# train: 100%|██████████| 17/17 [00:02<00:00,  7.42it/s, bce_loss - 0.3934, iou_score - 0.6865, fscore - 0.83, recall - 0.8487, precision - 0.8122]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.40it/s, bce_loss - 0.3941, iou_score - 0.6819, fscore - 0.8271, recall - 0.8563, precision - 0.8016]
#
# Epoch: 130
# train: 100%|██████████| 17/17 [00:02<00:00,  7.70it/s, bce_loss - 0.378, iou_score - 0.6902, fscore - 0.8353, recall - 0.8553, precision - 0.8163]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.28it/s, bce_loss - 0.397, iou_score - 0.6808, fscore - 0.8261, recall - 0.8554, precision - 0.8005]
#
# Epoch: 131
# train: 100%|██████████| 17/17 [00:02<00:00,  7.57it/s, bce_loss - 0.3913, iou_score - 0.6856, fscore - 0.8318, recall - 0.8535, precision - 0.8113]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.62it/s, bce_loss - 0.3972, iou_score - 0.6824, fscore - 0.8287, recall - 0.8585, precision - 0.8028]
#
# Epoch: 132
# train: 100%|██████████| 17/17 [00:02<00:00,  7.54it/s, bce_loss - 0.3874, iou_score - 0.6856, fscore - 0.8303, recall - 0.8505, precision - 0.811]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.91it/s, bce_loss - 0.4053, iou_score - 0.6832, fscore - 0.8253, recall - 0.8546, precision - 0.7997]
#
# Epoch: 133
# train: 100%|██████████| 17/17 [00:02<00:00,  7.59it/s, bce_loss - 0.3944, iou_score - 0.6859, fscore - 0.8293, recall - 0.8486, precision - 0.811]
# valid: 100%|██████████| 114/114 [00:01<00:00, 64.85it/s, bce_loss - 0.3983, iou_score - 0.6855, fscore - 0.8257, recall - 0.8551, precision - 0.8001]
#
# Epoch: 134
# train: 100%|██████████| 17/17 [00:02<00:00,  7.61it/s, bce_loss - 0.4181, iou_score - 0.6792, fscore - 0.8244, recall - 0.8452, precision - 0.8047]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.84it/s, bce_loss - 0.3923, iou_score - 0.6819, fscore - 0.827, recall - 0.8565, precision - 0.8013]
#
# Epoch: 135
# train: 100%|██████████| 17/17 [00:02<00:00,  7.47it/s, bce_loss - 0.3912, iou_score - 0.6859, fscore - 0.8307, recall - 0.8503, precision - 0.812]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.78it/s, bce_loss - 0.3894, iou_score - 0.6829, fscore - 0.8263, recall - 0.8558, precision - 0.8007]
#
# Epoch: 136
# train: 100%|██████████| 17/17 [00:02<00:00,  7.46it/s, bce_loss - 0.4042, iou_score - 0.6821, fscore - 0.8264, recall - 0.8456, precision - 0.808]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.89it/s, bce_loss - 0.3976, iou_score - 0.6829, fscore - 0.8247, recall - 0.8539, precision - 0.7992]
#
# Epoch: 137
# train: 100%|██████████| 17/17 [00:02<00:00,  7.50it/s, bce_loss - 0.4131, iou_score - 0.6802, fscore - 0.8242, recall - 0.8453, precision - 0.8044]
# valid: 100%|██████████| 114/114 [00:01<00:00, 63.93it/s, bce_loss - 0.3908, iou_score - 0.6819, fscore - 0.8271, recall - 0.8567, precision - 0.8012]
#
# Epoch: 138
# train: 100%|██████████| 17/17 [00:02<00:00,  7.71it/s, bce_loss - 0.4208, iou_score - 0.6816, fscore - 0.8256, recall - 0.8456, precision - 0.8066]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.59it/s, bce_loss - 0.3922, iou_score - 0.6829, fscore - 0.8264, recall - 0.8559, precision - 0.8006]
#
# Epoch: 139
# train: 100%|██████████| 17/17 [00:02<00:00,  7.52it/s, bce_loss - 0.4014, iou_score - 0.6818, fscore - 0.8291, recall - 0.8492, precision - 0.8099]
# valid: 100%|██████████| 114/114 [00:01<00:00, 64.69it/s, bce_loss - 0.3889, iou_score - 0.6839, fscore - 0.8299, recall - 0.8592, precision - 0.8044]
#
# Epoch: 140
# train: 100%|██████████| 17/17 [00:02<00:00,  7.64it/s, bce_loss - 0.3944, iou_score - 0.6849, fscore - 0.8295, recall - 0.85, precision - 0.8101]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.56it/s, bce_loss - 0.3765, iou_score - 0.6876, fscore - 0.8328, recall - 0.8624, precision - 0.807]
#
# Epoch: 141
# train: 100%|██████████| 17/17 [00:02<00:00,  7.61it/s, bce_loss - 0.3948, iou_score - 0.6846, fscore - 0.8271, recall - 0.8469, precision - 0.8084]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.19it/s, bce_loss - 0.385, iou_score - 0.6806, fscore - 0.8273, recall - 0.8571, precision - 0.8013]
#
# Epoch: 142
# train: 100%|██████████| 17/17 [00:02<00:00,  7.57it/s, bce_loss - 0.3997, iou_score - 0.6845, fscore - 0.8311, recall - 0.8522, precision - 0.8112]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.71it/s, bce_loss - 0.3923, iou_score - 0.6836, fscore - 0.8267, recall - 0.8567, precision - 0.8007]
#
# Epoch: 143
# train: 100%|██████████| 17/17 [00:02<00:00,  7.57it/s, bce_loss - 0.395, iou_score - 0.6885, fscore - 0.8319, recall - 0.8516, precision - 0.8132]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.31it/s, bce_loss - 0.3942, iou_score - 0.6801, fscore - 0.8249, recall - 0.8542, precision - 0.7993]
#
# Epoch: 144
# train: 100%|██████████| 17/17 [00:02<00:00,  7.62it/s, bce_loss - 0.3984, iou_score - 0.6826, fscore - 0.8291, recall - 0.8485, precision - 0.8107]
# valid: 100%|██████████| 114/114 [00:01<00:00, 64.16it/s, bce_loss - 0.3923, iou_score - 0.6826, fscore - 0.8272, recall - 0.8564, precision - 0.8018]
#
# Epoch: 145
# train: 100%|██████████| 17/17 [00:02<00:00,  7.47it/s, bce_loss - 0.3889, iou_score - 0.6889, fscore - 0.8325, recall - 0.8512, precision - 0.8147]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.00it/s, bce_loss - 0.4034, iou_score - 0.6767, fscore - 0.8208, recall - 0.8495, precision - 0.7958]
#
# Epoch: 146
# train: 100%|██████████| 17/17 [00:02<00:00,  7.64it/s, bce_loss - 0.4071, iou_score - 0.6807, fscore - 0.825, recall - 0.8447, precision - 0.8064]
# valid: 100%|██████████| 114/114 [00:01<00:00, 64.95it/s, bce_loss - 0.4072, iou_score - 0.6817, fscore - 0.8228, recall - 0.8517, precision - 0.7977]
#
# Epoch: 147
# train: 100%|██████████| 17/17 [00:02<00:00,  7.64it/s, bce_loss - 0.4077, iou_score - 0.6823, fscore - 0.8253, recall - 0.8453, precision - 0.8063]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.24it/s, bce_loss - 0.391, iou_score - 0.6814, fscore - 0.8304, recall - 0.8597, precision - 0.8048]
#
# Epoch: 148
# train: 100%|██████████| 17/17 [00:02<00:00,  7.51it/s, bce_loss - 0.4075, iou_score - 0.6826, fscore - 0.8278, recall - 0.8479, precision - 0.8088]
# valid: 100%|██████████| 114/114 [00:01<00:00, 64.86it/s, bce_loss - 0.3969, iou_score - 0.6825, fscore - 0.8258, recall - 0.8555, precision - 0.8]
#
# Epoch: 149
# train: 100%|██████████| 17/17 [00:02<00:00,  7.61it/s, bce_loss - 0.394, iou_score - 0.6838, fscore - 0.8294, recall - 0.8501, precision - 0.81]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.48it/s, bce_loss - 0.3852, iou_score - 0.6836, fscore - 0.8305, recall - 0.8598, precision - 0.8049]
#
# Epoch: 150
# train: 100%|██████████| 17/17 [00:02<00:00,  7.64it/s, bce_loss - 0.3985, iou_score - 0.685, fscore - 0.828, recall - 0.8469, precision - 0.8099]
# valid: 100%|██████████| 114/114 [00:01<00:00, 64.73it/s, bce_loss - 0.4033, iou_score - 0.6807, fscore - 0.825, recall - 0.8544, precision - 0.7994]
#
# Epoch: 151
# train: 100%|██████████| 17/17 [00:02<00:00,  7.66it/s, bce_loss - 0.3885, iou_score - 0.685, fscore - 0.83, recall - 0.8495, precision - 0.8115]
# valid: 100%|██████████| 114/114 [00:01<00:00, 64.84it/s, bce_loss - 0.392, iou_score - 0.683, fscore - 0.8265, recall - 0.8562, precision - 0.8006]
#
# Epoch: 152
# train: 100%|██████████| 17/17 [00:02<00:00,  7.42it/s, bce_loss - 0.4022, iou_score - 0.6802, fscore - 0.8258, recall - 0.8466, precision - 0.8062]
# valid: 100%|██████████| 114/114 [00:01<00:00, 64.36it/s, bce_loss - 0.3918, iou_score - 0.6865, fscore - 0.8301, recall - 0.8599, precision - 0.8041]
#
# Epoch: 153
# train: 100%|██████████| 17/17 [00:02<00:00,  7.70it/s, bce_loss - 0.3923, iou_score - 0.6873, fscore - 0.8313, recall - 0.851, precision - 0.8126]
# valid: 100%|██████████| 114/114 [00:01<00:00, 64.76it/s, bce_loss - 0.3964, iou_score - 0.6811, fscore - 0.8229, recall - 0.8524, precision - 0.7973]
#
# Epoch: 154
# train: 100%|██████████| 17/17 [00:02<00:00,  7.62it/s, bce_loss - 0.3868, iou_score - 0.6897, fscore - 0.8336, recall - 0.8526, precision - 0.8156]
# ...
#
# Epoch: 746
# train: 100%|██████████| 17/17 [00:02<00:00,  7.46it/s, bce_loss - 0.3959, iou_score - 0.6828, fscore - 0.8246, recall - 0.8454, precision - 0.805]
# valid: 100%|██████████| 114/114 [00:01<00:00, 64.87it/s, bce_loss - 0.3911, iou_score - 0.6821, fscore - 0.8264, recall - 0.8555, precision - 0.801]
#
# Epoch: 747
# train: 100%|██████████| 17/17 [00:02<00:00,  7.61it/s, bce_loss - 0.3931, iou_score - 0.6858, fscore - 0.8303, recall - 0.8498, precision - 0.8117]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.56it/s, bce_loss - 0.3838, iou_score - 0.6855, fscore - 0.8316, recall - 0.8611, precision - 0.8059]
#
# Epoch: 748
# train: 100%|██████████| 17/17 [00:02<00:00,  7.62it/s, bce_loss - 0.3853, iou_score - 0.69, fscore - 0.8327, recall - 0.8529, precision - 0.8134]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.21it/s, bce_loss - 0.3839, iou_score - 0.6863, fscore - 0.8297, recall - 0.8594, precision - 0.8039]
#
# Epoch: 749
# train: 100%|██████████| 17/17 [00:02<00:00,  7.61it/s, bce_loss - 0.3842, iou_score - 0.6893, fscore - 0.8329, recall - 0.8521, precision - 0.8147]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.67it/s, bce_loss - 0.4024, iou_score - 0.679, fscore - 0.8231, recall - 0.8526, precision - 0.7974]
#
# Epoch: 750
# train: 100%|██████████| 17/17 [00:02<00:00,  7.65it/s, bce_loss - 0.3973, iou_score - 0.6836, fscore - 0.8283, recall - 0.849, precision - 0.8087]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.13it/s, bce_loss - 0.389, iou_score - 0.6846, fscore - 0.8307, recall - 0.8604, precision - 0.8047]
#
# Epoch: 751
# train: 100%|██████████| 17/17 [00:02<00:00,  7.56it/s, bce_loss - 0.398, iou_score - 0.681, fscore - 0.8246, recall - 0.8442, precision - 0.806]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.11it/s, bce_loss - 0.3874, iou_score - 0.6868, fscore - 0.8293, recall - 0.8586, precision - 0.8037]
#
# Epoch: 752
# train: 100%|██████████| 17/17 [00:02<00:00,  7.54it/s, bce_loss - 0.3912, iou_score - 0.6839, fscore - 0.8283, recall - 0.8484, precision - 0.8092]
# valid: 100%|██████████| 114/114 [00:01<00:00, 64.27it/s, bce_loss - 0.3847, iou_score - 0.6886, fscore - 0.83, recall - 0.8594, precision - 0.8043]
#
# Epoch: 753
# train: 100%|██████████| 17/17 [00:02<00:00,  7.71it/s, bce_loss - 0.3948, iou_score - 0.6864, fscore - 0.8274, recall - 0.8468, precision - 0.809]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.49it/s, bce_loss - 0.3805, iou_score - 0.6858, fscore - 0.8313, recall - 0.8606, precision - 0.8058]
#
# Epoch: 754
# train: 100%|██████████| 17/17 [00:02<00:00,  7.61it/s, bce_loss - 0.3869, iou_score - 0.6872, fscore - 0.8312, recall - 0.8504, precision - 0.813]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.20it/s, bce_loss - 0.4044, iou_score - 0.6773, fscore - 0.821, recall - 0.8499, precision - 0.7957]
#
# Epoch: 755
# train: 100%|██████████| 17/17 [00:02<00:00,  7.53it/s, bce_loss - 0.3927, iou_score - 0.6846, fscore - 0.8297, recall - 0.8495, precision - 0.8109]
# valid: 100%|██████████| 114/114 [00:01<00:00, 64.74it/s, bce_loss - 0.3828, iou_score - 0.6872, fscore - 0.8282, recall - 0.8577, precision - 0.8025]
#
# Epoch: 756
# train: 100%|██████████| 17/17 [00:02<00:00,  7.65it/s, bce_loss - 0.3985, iou_score - 0.682, fscore - 0.8271, recall - 0.8459, precision - 0.8092]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.68it/s, bce_loss - 0.4031, iou_score - 0.6839, fscore - 0.825, recall - 0.8543, precision - 0.7995]
#
# Epoch: 757
# train: 100%|██████████| 17/17 [00:02<00:00,  7.54it/s, bce_loss - 0.3917, iou_score - 0.6863, fscore - 0.8289, recall - 0.8485, precision - 0.8102]
# valid: 100%|██████████| 114/114 [00:01<00:00, 64.89it/s, bce_loss - 0.3966, iou_score - 0.6822, fscore - 0.8242, recall - 0.8536, precision - 0.7986]
#
# Epoch: 758
# train: 100%|██████████| 17/17 [00:02<00:00,  7.64it/s, bce_loss - 0.3855, iou_score - 0.6852, fscore - 0.8318, recall - 0.8526, precision - 0.812]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.03it/s, bce_loss - 0.384, iou_score - 0.6843, fscore - 0.8294, recall - 0.8594, precision - 0.8033]
#
# Epoch: 759
# train: 100%|██████████| 17/17 [00:02<00:00,  7.44it/s, bce_loss - 0.4059, iou_score - 0.6834, fscore - 0.8295, recall - 0.8494, precision - 0.8106]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.22it/s, bce_loss - 0.383, iou_score - 0.6842, fscore - 0.8296, recall - 0.859, precision - 0.8039]
#
# Epoch: 760
# train: 100%|██████████| 17/17 [00:02<00:00,  7.65it/s, bce_loss - 0.3946, iou_score - 0.6836, fscore - 0.8288, recall - 0.848, precision - 0.8107]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.18it/s, bce_loss - 0.4015, iou_score - 0.6812, fscore - 0.8239, recall - 0.8529, precision - 0.7986]
#
# Epoch: 761
# train: 100%|██████████| 17/17 [00:02<00:00,  7.64it/s, bce_loss - 0.3974, iou_score - 0.682, fscore - 0.8276, recall - 0.8476, precision - 0.8086]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.26it/s, bce_loss - 0.4041, iou_score - 0.6803, fscore - 0.8242, recall - 0.8538, precision - 0.7984]
#
# Epoch: 762
# train: 100%|██████████| 17/17 [00:02<00:00,  7.63it/s, bce_loss - 0.3899, iou_score - 0.6864, fscore - 0.8319, recall - 0.8517, precision - 0.813]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.14it/s, bce_loss - 0.3982, iou_score - 0.6808, fscore - 0.8255, recall - 0.8547, precision - 0.8001]
#
# Epoch: 763
# train: 100%|██████████| 17/17 [00:02<00:00,  7.56it/s, bce_loss - 0.3897, iou_score - 0.6864, fscore - 0.8301, recall - 0.8504, precision - 0.8109]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.07it/s, bce_loss - 0.3851, iou_score - 0.6865, fscore - 0.833, recall - 0.8624, precision - 0.8074]
#
# Epoch: 764
# train: 100%|██████████| 17/17 [00:02<00:00,  7.66it/s, bce_loss - 0.3794, iou_score - 0.6893, fscore - 0.8357, recall - 0.8553, precision - 0.8171]
# valid: 100%|██████████| 114/114 [00:01<00:00, 64.84it/s, bce_loss - 0.3859, iou_score - 0.6845, fscore - 0.8306, recall - 0.8601, precision - 0.8049]
#
# Epoch: 765
# train: 100%|██████████| 17/17 [00:02<00:00,  7.55it/s, bce_loss - 0.4261, iou_score - 0.6782, fscore - 0.8213, recall - 0.8407, precision - 0.8029]
# valid: 100%|██████████| 114/114 [00:01<00:00, 64.97it/s, bce_loss - 0.4138, iou_score - 0.6815, fscore - 0.8228, recall - 0.8523, precision - 0.7971]
#
# Epoch: 766
# train: 100%|██████████| 17/17 [00:02<00:00,  7.55it/s, bce_loss - 0.389, iou_score - 0.6864, fscore - 0.8321, recall - 0.8524, precision - 0.8129]
# valid: 100%|██████████| 114/114 [00:01<00:00, 64.61it/s, bce_loss - 0.3854, iou_score - 0.6858, fscore - 0.8309, recall - 0.8604, precision - 0.8052]
#
# Epoch: 767
# train: 100%|██████████| 17/17 [00:02<00:00,  7.49it/s, bce_loss - 0.3912, iou_score - 0.6844, fscore - 0.8301, recall - 0.8511, precision - 0.8102]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.15it/s, bce_loss - 0.3902, iou_score - 0.6842, fscore - 0.8298, recall - 0.8595, precision - 0.8039]
#
# Epoch: 768
# train: 100%|██████████| 17/17 [00:02<00:00,  7.56it/s, bce_loss - 0.4221, iou_score - 0.6783, fscore - 0.8215, recall - 0.8421, precision - 0.802]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.46it/s, bce_loss - 0.3981, iou_score - 0.6833, fscore - 0.825, recall - 0.8541, precision - 0.7996]
#
# Epoch: 769
# train: 100%|██████████| 17/17 [00:02<00:00,  7.62it/s, bce_loss - 0.4007, iou_score - 0.683, fscore - 0.8284, recall - 0.8487, precision - 0.8091]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.73it/s, bce_loss - 0.3888, iou_score - 0.6848, fscore - 0.8291, recall - 0.8587, precision - 0.8034]
#
# Epoch: 770
# train: 100%|██████████| 17/17 [00:02<00:00,  7.44it/s, bce_loss - 0.3817, iou_score - 0.687, fscore - 0.832, recall - 0.8521, precision - 0.813]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.48it/s, bce_loss - 0.3868, iou_score - 0.6842, fscore - 0.8297, recall - 0.8594, precision - 0.8038]
#
# Epoch: 771
# train: 100%|██████████| 17/17 [00:02<00:00,  7.59it/s, bce_loss - 0.3867, iou_score - 0.6889, fscore - 0.8308, recall - 0.8502, precision - 0.8124]
# valid: 100%|██████████| 114/114 [00:01<00:00, 64.52it/s, bce_loss - 0.3947, iou_score - 0.6823, fscore - 0.8278, recall - 0.8571, precision - 0.8022]
#
# Epoch: 772
# train: 100%|██████████| 17/17 [00:02<00:00,  7.61it/s, bce_loss - 0.4015, iou_score - 0.6835, fscore - 0.8269, recall - 0.8466, precision - 0.8081]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.83it/s, bce_loss - 0.3909, iou_score - 0.6818, fscore - 0.8267, recall - 0.8559, precision - 0.8012]
#
# Epoch: 773
# train: 100%|██████████| 17/17 [00:02<00:00,  7.57it/s, bce_loss - 0.3978, iou_score - 0.6849, fscore - 0.8301, recall - 0.8494, precision - 0.8118]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.17it/s, bce_loss - 0.3879, iou_score - 0.6873, fscore - 0.8296, recall - 0.8592, precision - 0.8039]
#
# Epoch: 774
# train: 100%|██████████| 17/17 [00:02<00:00,  7.46it/s, bce_loss - 0.3861, iou_score - 0.6868, fscore - 0.8329, recall - 0.8528, precision - 0.814]
# valid: 100%|██████████| 114/114 [00:01<00:00, 64.88it/s, bce_loss - 0.3845, iou_score - 0.6852, fscore - 0.8316, recall - 0.8611, precision - 0.8059]
#
# Epoch: 775
# train: 100%|██████████| 17/17 [00:02<00:00,  7.68it/s, bce_loss - 0.3905, iou_score - 0.6851, fscore - 0.83, recall - 0.8511, precision - 0.81]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.19it/s, bce_loss - 0.3986, iou_score - 0.6813, fscore - 0.8269, recall - 0.8567, precision - 0.8009]
#
# Epoch: 776
# train: 100%|██████████| 17/17 [00:02<00:00,  7.70it/s, bce_loss - 0.3899, iou_score - 0.6875, fscore - 0.8314, recall - 0.8515, precision - 0.8123]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.93it/s, bce_loss - 0.3937, iou_score - 0.6832, fscore - 0.829, recall - 0.8584, precision - 0.8034]
#
# Epoch: 777
# train: 100%|██████████| 17/17 [00:02<00:00,  7.58it/s, bce_loss - 0.3947, iou_score - 0.6885, fscore - 0.8319, recall - 0.852, precision - 0.8128]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.34it/s, bce_loss - 0.3973, iou_score - 0.6823, fscore - 0.8255, recall - 0.8548, precision - 0.7999]
#
# Epoch: 778
# train: 100%|██████████| 17/17 [00:02<00:00,  7.61it/s, bce_loss - 0.4027, iou_score - 0.6813, fscore - 0.8255, recall - 0.8473, precision - 0.805]
# valid: 100%|██████████| 114/114 [00:01<00:00, 66.25it/s, bce_loss - 0.3947, iou_score - 0.6851, fscore - 0.8266, recall - 0.8563, precision - 0.8007]
#
# Epoch: 779
# train: 100%|██████████| 17/17 [00:02<00:00,  7.46it/s, bce_loss - 0.4024, iou_score - 0.684, fscore - 0.8292, recall - 0.849, precision - 0.8104]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.81it/s, bce_loss - 0.3962, iou_score - 0.6838, fscore - 0.8232, recall - 0.8525, precision - 0.7978]
#
# Epoch: 780
# train: 100%|██████████| 17/17 [00:02<00:00,  7.57it/s, bce_loss - 0.3895, iou_score - 0.6876, fscore - 0.8302, recall - 0.8493, precision - 0.8121]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.71it/s, bce_loss - 0.3974, iou_score - 0.6812, fscore - 0.8263, recall - 0.8554, precision - 0.8009]
#
# Epoch: 781
# train: 100%|██████████| 17/17 [00:02<00:00,  7.48it/s, bce_loss - 0.3913, iou_score - 0.6864, fscore - 0.8319, recall - 0.851, precision - 0.8137]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.23it/s, bce_loss - 0.3808, iou_score - 0.6901, fscore - 0.8324, recall - 0.862, precision - 0.8065]
#
# Epoch: 782
# train: 100%|██████████| 17/17 [00:02<00:00,  7.46it/s, bce_loss - 0.4057, iou_score - 0.6833, fscore - 0.828, recall - 0.8468, precision - 0.81]
# valid: 100%|██████████| 114/114 [00:01<00:00, 64.72it/s, bce_loss - 0.4036, iou_score - 0.6807, fscore - 0.8253, recall - 0.8547, precision - 0.7998]
#
# Epoch: 783
# train: 100%|██████████| 17/17 [00:02<00:00,  7.53it/s, bce_loss - 0.4031, iou_score - 0.6823, fscore - 0.8259, recall - 0.845, precision - 0.8078]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.69it/s, bce_loss - 0.3934, iou_score - 0.6813, fscore - 0.8274, recall - 0.8571, precision - 0.8015]
#
# Epoch: 784
# train: 100%|██████████| 17/17 [00:02<00:00,  7.48it/s, bce_loss - 0.4082, iou_score - 0.6805, fscore - 0.8267, recall - 0.8465, precision - 0.8079]
# valid: 100%|██████████| 114/114 [00:01<00:00, 64.76it/s, bce_loss - 0.4079, iou_score - 0.6757, fscore - 0.8175, recall - 0.8467, precision - 0.792]
#
# Epoch: 785
# train: 100%|██████████| 17/17 [00:02<00:00,  7.64it/s, bce_loss - 0.3838, iou_score - 0.6853, fscore - 0.8321, recall - 0.8525, precision - 0.8129]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.90it/s, bce_loss - 0.3882, iou_score - 0.6831, fscore - 0.8277, recall - 0.8568, precision - 0.8022]
#
# Epoch: 786
# train: 100%|██████████| 17/17 [00:02<00:00,  7.53it/s, bce_loss - 0.3983, iou_score - 0.683, fscore - 0.8256, recall - 0.8454, precision - 0.8068]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.32it/s, bce_loss - 0.3951, iou_score - 0.6823, fscore - 0.8257, recall - 0.8553, precision - 0.8]
#
# Epoch: 787
# train: 100%|██████████| 17/17 [00:02<00:00,  7.67it/s, bce_loss - 0.3937, iou_score - 0.6856, fscore - 0.8283, recall - 0.8481, precision - 0.8095]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.44it/s, bce_loss - 0.3926, iou_score - 0.6845, fscore - 0.8294, recall - 0.8586, precision - 0.8039]
#
# Epoch: 788
# train: 100%|██████████| 17/17 [00:02<00:00,  7.62it/s, bce_loss - 0.3844, iou_score - 0.6888, fscore - 0.8319, recall - 0.8505, precision - 0.8142]
# valid: 100%|██████████| 114/114 [00:01<00:00, 64.89it/s, bce_loss - 0.3891, iou_score - 0.6833, fscore - 0.8272, recall - 0.8561, precision - 0.802]
#
# Epoch: 789
# train: 100%|██████████| 17/17 [00:02<00:00,  7.47it/s, bce_loss - 0.385, iou_score - 0.6873, fscore - 0.8295, recall - 0.849, precision - 0.811]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.43it/s, bce_loss - 0.3891, iou_score - 0.6814, fscore - 0.8294, recall - 0.859, precision - 0.8036]
#
# Epoch: 790
# train: 100%|██████████| 17/17 [00:02<00:00,  7.51it/s, bce_loss - 0.3882, iou_score - 0.6862, fscore - 0.831, recall - 0.8517, precision - 0.8114]
# valid: 100%|██████████| 114/114 [00:01<00:00, 64.93it/s, bce_loss - 0.3834, iou_score - 0.6876, fscore - 0.8348, recall - 0.8648, precision - 0.8086]
#
# Epoch: 791
# train: 100%|██████████| 17/17 [00:02<00:00,  7.57it/s, bce_loss - 0.3954, iou_score - 0.6836, fscore - 0.8296, recall - 0.8502, precision - 0.8101]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.61it/s, bce_loss - 0.3919, iou_score - 0.6842, fscore - 0.8311, recall - 0.8611, precision - 0.8049]
#
# Epoch: 792
# train: 100%|██████████| 17/17 [00:02<00:00,  7.55it/s, bce_loss - 0.3886, iou_score - 0.6853, fscore - 0.8297, recall - 0.8491, precision - 0.8113]
# valid: 100%|██████████| 114/114 [00:01<00:00, 64.48it/s, bce_loss - 0.4015, iou_score - 0.6799, fscore - 0.8248, recall - 0.8542, precision - 0.7992]
#
# Epoch: 793
# train: 100%|██████████| 17/17 [00:02<00:00,  7.62it/s, bce_loss - 0.3888, iou_score - 0.6875, fscore - 0.8301, recall - 0.8497, precision - 0.8115]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.68it/s, bce_loss - 0.3795, iou_score - 0.6842, fscore - 0.833, recall - 0.863, precision - 0.8068]
#
# Epoch: 794
# train: 100%|██████████| 17/17 [00:02<00:00,  7.65it/s, bce_loss - 0.3975, iou_score - 0.6827, fscore - 0.8253, recall - 0.8457, precision - 0.806]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.57it/s, bce_loss - 0.4035, iou_score - 0.6826, fscore - 0.8263, recall - 0.8558, precision - 0.8006]
#
# Epoch: 795
# train: 100%|██████████| 17/17 [00:02<00:00,  7.52it/s, bce_loss - 0.3884, iou_score - 0.6849, fscore - 0.8304, recall - 0.8509, precision - 0.8111]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.05it/s, bce_loss - 0.3914, iou_score - 0.6858, fscore - 0.8336, recall - 0.8632, precision - 0.8078]
#
# Epoch: 796
# train: 100%|██████████| 17/17 [00:02<00:00,  7.62it/s, bce_loss - 0.3992, iou_score - 0.6848, fscore - 0.8246, recall - 0.8437, precision - 0.8066]
# valid: 100%|██████████| 114/114 [00:01<00:00, 65.37it/s, bce_loss - 0.3956, iou_score - 0.6854, fscore - 0.8268, recall - 0.8561, precision - 0.8013]
#
# Epoch: 797
# train:  94%|█████████▍| 16/17 [00:02<00:00,  9.97it/s, bce_loss - 0.4088, iou_score - 0.6828, fscore - 0.8278, recall - 0.8476, precision - 0.8091]

# %% [markdown]
# ### Prediction on Test Data

# %%
# load best saved model checkpoint from the first run
if os.path.exists(os.path.join(DATA_DIR,'best_model_u.pth')):
    best_model = torch.load(os.path.join(DATA_DIR,'best_model_u.pth'), map_location=DEVICE)
    print('Loaded UNet model from this run.')

# load best saved model checkpoint from previous commit (if present)
elif os.path.exists(os.path.join(DATA_DIR,'best_model.pth')):
    best_model = torch.load(os.path.join(DATA_DIR,'best_model.pth'), map_location=DEVICE)
    print('Loaded UNet model from a previous commit.')
else:
    print('fail to load model')

# ../data/tiff_v3/128
# best_model = torch.load(os.path.join('../data/tiff_v3/256','best_model_u256.pth'), map_location=DEVICE)

# %%
# create test dataloader (with preprocessing operation: to_tensor(...))
test_dataset = BuildingsDataset(
    os.path.join(DATA_DIR,'test'), #'../data/tiff_v3/128_modified_pre/'
    os.path.join(DATA_DIR,'test_labels'),
    # x_test_dir, 
    # y_test_dir, 
    # x_train_dir, 
    # y_train_dir, 
    augmentation=get_validation_augmentation(), 
    preprocessing=get_preprocessing(preprocessing_fn),
    class_rgb_values=select_class_rgb_values,
)

test_dataloader = DataLoader(test_dataset)

# test dataset for visualization (without preprocessing transformations)
test_dataset_vis = BuildingsDataset(
    os.path.join(DATA_DIR,'test'),
    os.path.join(DATA_DIR,'test_labels'),
    # x_test_dir, 
    # y_test_dir, 
    # x_train_dir, 
    # y_train_dir, 
    augmentation=get_validation_augmentation(),
    class_rgb_values=select_class_rgb_values,
)

# get a random test image/mask index
random_idx = random.randint(0, len(test_dataset_vis)-1)
image, mask = test_dataset_vis[random_idx]

visualize(
    original_image = image,
    ground_truth_mask = colour_code_segmentation(reverse_one_hot(mask), select_class_rgb_values),
    one_hot_encoded_mask = reverse_one_hot(mask)
)

# Notice the images / masks are 1536*1536 because of 18px padding on all sides. 
# This is to ensure the input image dimensions to UNet model are a multiple of 2 (to account for pooling & transpose conv. operations).

# %%
# Center crop padded image / mask to original image dims
def crop_image(image, target_image_dims=[1500,1500,3]):
   
    target_size = target_image_dims[0]
    image_size = len(image)
    padding = (image_size - target_size) // 2

    return image[
        padding:image_size - padding,
        padding:image_size - padding,
        :,
    ]

# %%
sample_preds_folder = os.path.join(DATA_DIR,'sample_predictions_damaged_test_all_v3_smooth_128best_model_v3/')
if not os.path.exists(sample_preds_folder):
    os.makedirs(sample_preds_folder)

# %%
for idx in range(len(test_dataset)):

    image, gt_mask = test_dataset[idx]
    image_vis = crop_image(test_dataset_vis[idx][0].astype('uint8'))
    x_tensor = torch.from_numpy(image).to(DEVICE).unsqueeze(0)
    # Predict test image
    pred_mask = best_model(x_tensor)
    pred_mask = pred_mask.detach().squeeze().cpu().numpy()
    # Convert pred_mask from `CHW` format to `HWC` format
    pred_mask = np.transpose(pred_mask,(1,2,0))
    # Get prediction channel corresponding to building
    pred_building_heatmap = pred_mask[:,:,select_classes.index('building')]
    pred_mask = crop_image(colour_code_segmentation(reverse_one_hot(pred_mask), select_class_rgb_values))
    # Convert gt_mask from `CHW` format to `HWC` format
    gt_mask = np.transpose(gt_mask,(1,2,0))
    gt_mask = crop_image(colour_code_segmentation(reverse_one_hot(gt_mask), select_class_rgb_values))
    #fname = fname.split('/')[-1]
#     cv2.imwrite(os.path.join(sample_preds_folder, f"{idx}.png"), np.hstack([image_vis, gt_mask, pred_mask])[:,:,::-1])
#     cv2.imwrite(os.path.join(sample_preds_folder, f"{idx}_mask.png"), pred_mask)
    
    
    visualize(
        original_image = image_vis,
        ground_truth_mask = gt_mask,
        predicted_mask = pred_mask,
        predicted_building_heatmap = pred_building_heatmap
    )

# %%
# for idx in range(len(test_dataset)):

#     image, gt_mask = test_dataset[idx]
#     image_vis = crop_image(test_dataset_vis[idx][0].astype('uint8'))
#     x_tensor = torch.from_numpy(image).to(DEVICE).unsqueeze(0)
#     # Predict test image
#     pred_mask = best_model(x_tensor)
#     pred_mask = pred_mask.detach().squeeze().cpu().numpy()
#     # Convert pred_mask from `CHW` format to `HWC` format
#     pred_mask = np.transpose(pred_mask,(1,2,0))
#     # Get prediction channel corresponding to building
#     pred_building_heatmap = pred_mask[:,:,select_classes.index('building')]
#     pred_mask = crop_image(colour_code_segmentation(reverse_one_hot(pred_mask), select_class_rgb_values))
#     # Convert gt_mask from `CHW` format to `HWC` format
#     gt_mask = np.transpose(gt_mask,(1,2,0))
#     gt_mask = crop_image(colour_code_segmentation(reverse_one_hot(gt_mask), select_class_rgb_values))
#     cv2.imwrite(os.path.join(sample_preds_folder, f"sample_pred_{idx}.png"), np.hstack([image_vis, gt_mask, pred_mask])[:,:,::-1])
    
#     visualize(
#         original_image = image_vis,
#         ground_truth_mask = gt_mask,
#         predicted_mask = pred_mask,
#         predicted_building_heatmap = pred_building_heatmap
#     )

# %% [markdown]
# ### Model Evaluation on Test Dataset

# %%
test_epoch = utils.train.ValidEpoch( 
    model,
    loss=loss, 
    metrics=metrics, 
    device=DEVICE,
    verbose=True,
)

valid_logs = test_epoch.run(test_dataloader)
print("Evaluation on Test Data: ")
print(f"Mean IoU Score: {valid_logs['iou_score']:.4f}")
#print(f"Mean Dice Loss: {valid_logs['dice_loss']:.4f}")

# %% [markdown]
# ### Plot IoU & Fscore Metric for Train vs. Val

# %%
train_logs_df = pd.DataFrame(train_logs_list)
valid_logs_df = pd.DataFrame(valid_logs_list)
train_logs_df.T

# %%
valid_logs_df.T

# %%
plt.figure(figsize=(20,8))
plt.plot(train_logs_df.index.tolist(), train_logs_df.iou_score.tolist(), lw=3, label = 'Train')
plt.plot(valid_logs_df.index.tolist(), valid_logs_df.iou_score.tolist(), lw=3, label = 'Valid')
plt.xlabel('Epochs', fontsize=20)
plt.ylabel('IoU Score', fontsize=20)
plt.title('IoU Score Plot', fontsize=20)
plt.legend(loc='best', fontsize=16)
plt.grid()
plt.savefig(os.path.join(DATA_DIR,'images/iou_score_plot.png'))
plt.show()

# %%
plt.figure(figsize=(20,8))
plt.plot(train_logs_df.index.tolist(), train_logs_df.fscore.tolist(), lw=3, label = 'Train')
plt.plot(valid_logs_df.index.tolist(), valid_logs_df.fscore.tolist(), lw=3, label = 'Valid')
plt.xlabel('Epochs', fontsize=20)
plt.ylabel('Fscore', fontsize=20)
plt.title('Fscore Plot', fontsize=20)
plt.legend(loc='best', fontsize=16)
plt.grid()
plt.savefig(os.path.join(DATA_DIR, 'images/fscore_plot.png'))
plt.show()

# %%
test_epoch = utils.train.ValidEpoch( 
    model,
    loss=loss, 
    metrics=metrics, 
    device=DEVICE,
    verbose=True,
)

valid_logs = test_epoch.run(test_dataloader)
print("Evaluation on Test Data: ")
print(f"Mean IoU Score: {valid_logs['iou_score']:.4f}")
#print(f"Mean Dice Loss: {valid_logs['dice_loss']:.4f}")

# %% [markdown]
# ### Plot IoU & Fscore Metric for Train vs. Val

# %%
train_logs_df = pd.DataFrame(train_logs_list)
valid_logs_df = pd.DataFrame(valid_logs_list)
train_logs_df.T

# %%
valid_logs_df.T

# %%
plt.figure(figsize=(20,8))
plt.plot(train_logs_df.index.tolist(), train_logs_df.iou_score.tolist(), lw=3, label = 'Train')
plt.plot(valid_logs_df.index.tolist(), valid_logs_df.iou_score.tolist(), lw=3, label = 'Valid')
plt.xlabel('Epochs', fontsize=20)
plt.ylabel('IoU Score', fontsize=20)
plt.title('IoU Score Plot', fontsize=20)
plt.legend(loc='best', fontsize=16)
plt.grid()
plt.savefig(DATA_DIR+'images/iou_score_plot.png')
plt.show()

# %%
plt.figure(figsize=(20,8))
plt.plot(train_logs_df.index.tolist(), train_logs_df.fscore.tolist(), lw=3, label = 'Train')
plt.plot(valid_logs_df.index.tolist(), valid_logs_df.fscore.tolist(), lw=3, label = 'Valid')
plt.xlabel('Epochs', fontsize=20)
plt.ylabel('Fscore', fontsize=20)
plt.title('Fscore Plot', fontsize=20)
plt.legend(loc='best', fontsize=16)
plt.grid()
plt.savefig(DATA_DIR+'images/fscore_plot.png')
plt.show()
